# %% [markdown]
# #Categories

# %%
categories_page = requests.get(
    'https://www.googleapis.com/youtube/v3/videoCategories',
    params={
        'part': 'snippet',
        'regionCode': 'RU',
        'key': API_key
    })

categories_res = categories_page.json()
categories_res['items'][0]

# {'kind': 'youtube#videoCategory',
#  'etag': 'grPOPYEUUZN3ltuDUGEWlrTR90U',
#  'id': '1',
#  'snippet': {'title': 'Film & Animation',
#   'assignable': True,
#   'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}

# %% [markdown]
# #Search

# %%
page = requests.get(
    f'https://www.googleapis.com/youtube/v3/search',
    params={
        'part': 'snippet',
        'q': company_name,
        'type': 'video',
        'maxResults': 5,
        'key': API_key
    },
    headers={'accept': 'application/json'})

res = page.json()
res['items'][0]

# {'kind': 'youtube#searchResult',
#  'etag': 'pz0unXbYwYvVs5tgh176LPNRrHs',
#  'id': {'kind': 'youtube#video', 'videoId': 'DdgF7gE6UOI'},
#  'snippet': {'publishedAt': '2026-04-08T09:30:08Z',
#   'channelId': 'UCU_MFRKmEA-sup7gg_RnNew',
#   'title': 'ЯНДЕКС ГРУЗОВОЙ, МАЛЫЙ КУЗОВ S / ДВА ГРУЗЧИКА / РАБОТА НА СВОЕМ АВТО ТИПА &quot;КАБЛУК&quot; / ПИТЕР',
#   'description': 'Всем привет! Вышли с Артемием поработать в два грузчика на молом кузове в тарифе грузовой. Получился очень ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DdgF7gE6UOI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/DdgF7gE6UOI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/DdgF7gE6UOI/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'ЛЕНИВЫЙ',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2026-04-08T09:30:08Z'}}

# %% [markdown]
# #Videos

# %%
videos_page = requests.get(
    'https://www.googleapis.com/youtube/v3/videos',
    params={
        'part': 'snippet,statistics,contentDetails',
        'id': ','.join(video_ids),
        'key': API_key
    }
)

videos_res = videos_page.json()
videos_res['items'][0]

# {'kind': 'youtube#video',
#  'etag': 'E6DpRQdrjWvX8S1ZoeU1skjMDOI',
#  'id': 'DdgF7gE6UOI',
#  'snippet': {'publishedAt': '2026-04-08T09:30:08Z',
#   'channelId': 'UCU_MFRKmEA-sup7gg_RnNew',
#   'title': 'ЯНДЕКС ГРУЗОВОЙ, МАЛЫЙ КУЗОВ S / ДВА ГРУЗЧИКА / РАБОТА НА СВОЕМ АВТО ТИПА "КАБЛУК" / ПИТЕР',
#   'description': 'Всем привет! Вышли с Артемием поработать в два грузчика на молом кузове в тарифе грузовой. Получился очень насыщенный день, в прочем как и всегда!\n\nПиши в БОТ Парка БОГАТЫЙ КУРЬЕР для регистрации в Яндекс Доставке\n⬇️⬇️⬇️\nhttps://t.me/BogatiyKurierBot?start=yr_a834314487964acca2b63d794d1d52dd\n\nПреимущества регистрации в нашем Парке:\n- Получить ссылку на ЧАТ с действующими курьерами по твоему городу\n- Принять участие в турнире
#    'РАБОТА КУРЬЕРОМ',
#    'РАБОТА В ЯНДЕКС',
#    'ТАРИФ ЭКСПРЕСС',
#    'ТАРИФ КУРЬЕР',
#    'ДОСТАВКА СПБ',
#    'ДОСТАВКА ПИТЕР',
#    'КУРЬЕР СПБ',
#    'КУРЬЕР ПИТЕР',
#    'РАБОТА В ДОСТАВКЕ',
#    'ДОСТАВКА НА СВОЕЙ МАШИНЕ',
#    'ДОСТАВКА НА АВТО',
#    'ДОСТАВКА НА АВТОМОБИЛЕ',
#    'КУРЬЕР НА АВТО',
#    'КУРЬЕР НА АВТОМОБИЛЕ',
#    'КУРЬЕР НА МАШИНЕ',
#    'КУРЬЕР САНКТ-ПЕТЕРБУРГ',
#    'ЯНДЕКС ПРО',
#    'ДОСТАВКА ЯНДЕКС ПРО',
#    'РАБОТА НА АВТОМОБИЛЕ',
#    'РАБОТА НА АВТО',
#    'РАБОТА НА МАШИНЕ',
#    'ДОСТАВКА ПРОДУКТОВ',
#    'ДОСТАВКА ЕДЫ',
#    'РАБОТА ДОСТАВЩИКОМ',
#    'ПОДРАБОТКА КУРЬЕРОМ'],
#   'categoryId': '2',
#   'liveBroadcastContent': 'none',
#   'defaultLanguage': 'ru',
#   'localized': {'title': 'ЯНДЕКС ГРУЗОВОЙ, МАЛЫЙ КУЗОВ S / ДВА ГРУЗЧИКА / РАБОТА НА СВОЕМ АВТО ТИПА "КАБЛУК" / ПИТЕР',
#    'description': 'Всем привет! Вышли с Артемием поработать в два грузчика на молом кузове в тарифе грузовой. Получился очень насыщенный день, в прочем как и всегда!\n\nПиши в БОТ Парка БОГАТЫЙ КУРЬЕР для регистрации в Яндекс Доставке\n⬇️⬇️⬇️\nhttps://t.me/BogatiyKurierBot?start=yr_a834314487964acca2b63d794d1d52dd\n\nПреимущества регистрации в нашем Парке:\n- Получить ссылку на ЧАТ с действующими курьерами по твоему городу\n- Принять участие в турнире на 120.000р\n- Получить видео-обучение, как выйти на доход от 80.000р в доставке\n- Получить ДЕНЬ БЕЗ КОМИССИИ\nОТВЕЧАЮТ ЖИВЫЕ МЕНЕДЖЕРЫ\n\nWhatsApp парка⬇️\nhttps://wa.me/79584983049\n\nТелефон парка⬇️\n+7 (958) 498-30-49\n\nТелеграм КАНАЛ \nс новостями о доставке и прямыми эфирами⬇️\nhttps://t.me/Bogatiykurier \n\nЮтуб канал парка БОГАТЫЙ КУРЬЕР⬇️\nhttps://youtube.com/@BogatiyKurier\n\n________________________________________________________________________________________________\n⭐ СОТРУДНИЧЕСТВО (НЕ ПРЕВЬЮ)⭐\n            https://t.me/leniviy_78\n________________________________________________________________________________________________\n➤ Поддержать ЛЕНИВОГО можно тут:   \nhttps://tips.yandex.ru/guest/payment/6552460\n\n➤ Официальный телеграм канал ЛЕНИВОГО\nhttps://t.me/+afl177AHnrw1ODNi  (тут можно скачать радар кэфа)\n\n➤ Телеграм ЧАТ ЛЕНИВОГО:\nhttps://t.me/+yxXTiXEpmiFhMGMy\n\n➤ ЛЕНИВЫЙ на RuTube:\nhttps://rutube.ru/channel/25363329/\n\n➤ЛЕНИВЫЙ на VKвидео: \nhttps://vk.com/leniviy_78\n\n➤ Донаты на развитие канала:\nhttps://www.donationalerts.com/r/lenivec700\n\n________________________________________________________________________________________________\nЯНДЕКС ГРУЗОВОЙ, МАЛЫЙ КУЗОВ, РАБОТА КУРЬЕРОМ, РАБОТА В ЯНДЕКС, ТАРИФ ГРУЗОВОЙ, СРЕДНИЙ КУЗОВ, КУЗОВ М, ДОСТАВКА ПИТЕР, КУРЬЕР СПБ, КУРЬЕР ПИТЕР, РАБОТА В ДОСТАВКЕ, ДОСТАВКА НА СВОЕЙ МАШИНЕ, ДОСТАВКА НА АВТО, ДОСТАВКА НА АВТОМОБИЛЕ, КУРЬЕР НА АВТО, КУРЬЕР НА АВТОМОБИЛЕ, КУРЬЕР НА МАШИНЕ, КУРЬЕР САНКТ-ПЕТЕРБУРГ, ЯНДЕКС ПРО, ДОСТАВКА ЯНДЕКС ПРО, РАБОТА НА АВТОМОБИЛЕ, РАБОТА НА АВТО, РАБОТА НА МАШИНЕ, РАБОТА ДОСТАВЩИКОМ, ПОДРАБОТКА КУРЬЕРОМ'},
#   'defaultAudioLanguage': 'ru'},
#  'contentDetails': {'duration': 'PT30M18S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensedContent': False,
#   'contentRating': {},
#   'projection': 'rectangular'},
#  'statistics': {'viewCount': '4089',
#   'likeCount': '220',
#   'favoriteCount': '0',
#   'commentCount': '64'}}

# %% [markdown]
# #Channels

# %%
channels_page = requests.get(
    'https://www.googleapis.com/youtube/v3/channels',
    params={
        'part': 'statistics',
        'id': ','.join(channel_ids),
        'key': API_key
    }
)

channels_res = channels_page.json()
channels_res['items'][0]

# {'kind': 'youtube#channel',
#  'etag': 'zvmvcCADDXKIHruF22AmYXM7k4E',
#  'id': 'UCU_MFRKmEA-sup7gg_RnNew',
#  'statistics': {'viewCount': '2498917',
#   'subscriberCount': '14000',
#   'hiddenSubscriberCount': False,
#   'videoCount': '313'}}

# %% [markdown]
# ----

# %% [markdown]
# #Smart Ranking (top 100 Bigtech)

# %% [markdown]
# ![Снимок экрана 2026-04-09 в 17.14.03.png](data:image/png;base64,...)

# %% [markdown]
# В каждом классе tr лежит вся информация о компании. В каждом отдельном td информация об отдельном признаке для компании (название, выручка и тд):
#
# Компания (Первый элемент до запятой в столбце Основные бренды -tbody - tr - второе td - первый элемент)
# Место в рейтинге - tbody - tr - td class = dt-type-numeric sorting_1
# Основной рынок - четвертый td в той же родительской вершине
# Выручка - шестой td в той же родительской вершине
# Прирост - седьмой td в той же родительской вершине
