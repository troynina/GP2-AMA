# %%
import requests

# %%
url = 'https://dreamjob.ru/categories' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %%
page
# Out:
# <Response [200]>

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from bs4) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup

# %%
page.text
# Out:
# '    <!DOCTYPE html>\n    <html lang="ru">\n    <head>\n        <meta charset="UTF-8"><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1134516852",accountID:"4709628",trustKey:"4709628",xpid:"UAEHWFBRABABVVBTBQcDXlwI",licenseKey:"NRJS-26e44a76514b85cdf44",applicationID:"1111264889",browserID:"1134516852"};;/*! For license information please see nr-loader-spa-1.312.1.min.js.LICENSE.txt */\n(()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,Zm:()=>c,bQ:()=>u,dV:()=>d,pV:()=>l});var n=r(6154),i=r(1863),s=r(944),o=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function c(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function d(){let e=c();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,o.i)(...Object.values(e.o))),e}function u(e,t){let r=c();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t,2===Object.keys(r.initializedAgents).length&&(0,s.R)(69)}function l(){return function(){let e=c();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=c();const t=e.init||{};e.init={...t}}(),d(),function(){let e=c();const t=e.loader_config||{};e.loader_config={...t}}(),c()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>a,df:()=>s,qY:()=>n,v4:()=>o});const n="events",i="jserrors",s="browser/blobs",o="rum",a="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.softNav]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.sessionReplay]:8,[c.logging]:9,[c.genericEvents]:10},u={[c.pageViewEvent]:o,[c.pageViewTiming]:n,[c.ajax]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:a,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>o,TZ:()=>a,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},o="log",a=n.K7.logging},1541:(e,t,r)=>{"use strict";r.d(t,{$5:()=>d,B5:()=>c,Ux:()=>o,YA:()=>a,fQ:()=>i});var n=r(5871);const i={MFE:"MFE",BA:"BA"};function s(e,t){if(!e||!t?.init.api.allow_registered_children)return[];const r=t.runtime.registeredEntities;return r?.filter(t=>t.metadata.timings?.asset?.endsWith(e)).map(e=>e.metadata.target)||[]}function o(e,t){if(!u(t))return{};const r=t.agentRef.runtime.appMetadata.agents[0].entityGuid;return e?e.attributes:{"entity.guid":r,appId:t.agentRef.info.applicationID}}function a(e,t){return c(e,t)?{"child.id":e.id,"child.type":e.type,...o(void 0,t)}:{}}function c(e,t){return!!e&&!!u(t)&&t.agentRef.init.api.duplicate_registered_data}function d(e){if(!e?.init.api.allow_registered_children)return[void 0];const t=[];try{var r=(0,n.AZ)((0,n.QL)());let i=r.length-1;for(;r[i];)t.push(...s(r[i--],e))}catch(e){}return t.length||t.push(void 0),t}function u(e){return 2===e?.harvestEndpointVersion}},168 ...

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1134516852",accountID:"4709628",trustKey:"4709628",xpid:"UAEHWFBRABABVVBTBQcDXlwI",licenseKey:"NRJS-26e44a76514b85cdf44",applicationID:"1111264889",browserID:"1134516852"};;/*! For license information please see nr-loader-spa-1.312.1.min.js.LICENSE.txt */
# (()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,Zm:()=>c,bQ:()=>u,dV:()=>d,pV:()=>l});var n=r(6154),i=r(1863),s=r(944),o=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function c(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function d(){let e=c();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,o.i)(...Object.values(e.o))),e}function u(e,t){let r=c();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t,2===Object.keys(r.initializedAgents).length&&(0,s.R)(69)}function l(){return function(){let e=c();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=c();const t=e.init||{};e.init={...t}}(),d(),function(){let e=c();const t=e.loader_config||{};e.loader_config={...t}}(),c()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>a,df:()=>s,qY:()=>n,v4:()=>o});const n="events",i="jserrors",s="browser/blobs",o="rum",a="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.softNav]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.sessionReplay]:8,[c.logging]:9,[c.genericEvents]:10},u={[c.pageViewEvent]:o,[c.pageViewTiming]:n,[c.ajax]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:a,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>o,TZ:()=>a,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},o="log",a=n.K7.logging},1541:(e,t,r)=>{"use strict";r.d(t,{$5:()=>d,B5:()=>c,Ux:()=>o,YA:()=>a,fQ:()=>i});var n=r(5871);const i={MFE:"MFE",BA:"BA"};function s(e,t){if(!e||!t?.init.api.allow_registered_children)return[];const r=t.runtime.registeredEntities;return r?.filter(t=>t.metadata.timings?.asset?.endsWith(e)).map(e=>e.metadata.target)||[]}function o(e,t){if(!u(t))return{};const r=t.agentRef.runtime.appMetadata.agents[0].entityGuid;return e?e.attributes:{"entity.guid":r,appId:t.agentRef.info.applicationID}}function a(e,t){return c(e,t)?{"child.id":e.id,"child.type":e.type,...o(void 0,t)}:{}}function c(e,t){return!!e&&!!u(t)&&t.agentRef.init.api.duplicate_registered_data}function d(e){if(!e?.init.api.allow_registered_children)return[void 0];const t=[];try{var r=(0,n.AZ)((0,n.QL)());let i=r.length-1;for(;r[i];)t.push(...s(r[i--],e))}catch(e){}return t.length||t.push(void 0),t}function u(e){return 2===e?.harvestEndpointVersion}},1687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>a,Ze:()=>d,x3:()=>c});var n=r(3241),i=r(3606),s=r(860),o=r(2646);function a(e,t){if(!e)return;const r={staged:!1,priority:s.P3[t]||0};e.runtime.drainRegistry.get(t)||e.runtime.drainRegistry.set(t,r)}function c(e,t){if(!e)return;const r=e.runtime.drainRegistry;r&&(r.get(t)&&r.delete(t),l(e,t,!1),r.size&&u(e))}function d(e,t="feature",r=!1){if(e){if(!e.runtime.drainRegistry.get(t)||r)return l(e,t);e.runtime.drainRegistry.get(t).staged=!0,u(e)}}function u(e){if(!e)return;const t=Array.from(e.runtime.drainRegistry);t.every(([e,t])=>t.staged)&&(t.so ...
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Каталог предприятий, компаний России по сферам деятельности | Dream Job</title>
# <meta content="https://dreamjob.ru/categories" property="og:url"/>
# <meta content="https://dreamjob.ru/i/dream-job.png" property="og:image"/>
# <meta content="Dream Job - крупнейший ресурс с отзывами сотрудников в России" property="og:image:alt"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1600" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Самый полный каталог предприятий, компаний России по сферам деятельности. Узнайте информацию о лидерах отрасли, просмотрите оценки, почитайте отзывы сотрудников — вся необходимая информация в одном месте Dream Job" name="description"/>
# <link href="https://dreamjob.ru/categories" rel="canonical"/>
# <link href="/assets/10afff40/themes/smoothness/jquery-ui.min.css?v=1473979674" rel="stylesheet"/>
# <link href="/css/bs-4.6.1-dj.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead-kv.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/38b60184/css/kv-widgets.min.css?v=1654067138" rel="stylesheet"/>
# <link href="/css/roboto_font.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/general-styles.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/header-main.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/dj/pages/categories.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/assets/c3ae0fcc/css/centrifuge.css?v=1773644461" rel="stylesheet"/>
# <script>window.typeahead_3fe4d359 = {"highlight":true,"minLength":2};
# </script>
# <script src="/js/fp_2_0_6.min.js"></script>
# <script>
#     Fingerprint2.get(function (cs) {
#         (function (w, d, s, l, i, c, fp, u, e, h) {
#             w[l] = w[l] || [];
#             w['fingerprint'] = {cs: cs, id: fp, uid: u, eid: e, hid: h};
#             w[l].push({fingerprint: fp});
#             if (u) w[l].push({user_id: u});
#             if (e) w[l].push({employer_id: e});
#             w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             try {
#                 c = JSON.parse(c);
#                 for (let p of Object.keys(c)) {
#                     w[l].push({event: 'FlagAssigned', 'flag_id': p, 'flag_is_on': c[p]});
#                 }
#             } catch (e) {
#             }
#                         /* Google Tag Manager */
#
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#             /* End Google Tag Manager */
#                     })(window, document, 'script', 'dataLayer', 'GTM-M3XGKC6', '',
#             Fingerprint2.x64hash128(cs.map(function (pair) {
#                 return pair.value
#             }).join(), 31), 0);
#     });
# </script> <meta content="_csrf" name="csrf-param"/>
# <meta content="ApKOhP02V7cstxADrcbgMoKMBgNo8RY2NAEqmGuvvvh0y6PWqAA2wRz6VE3G8L945_V1Rx6AXQMCZxr6GPrymw==" name="csrf-token"/>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3XGKC6" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script>var centrifugoOptions = {"wsConnectionEndpoint":"wss:\/\/centrifugo.dreamjob.ru:443\/connection\/websocket","connectionToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmZjQ2OTQ4YjY3N2M0N2Y3NDIxNDY2ZDU1NjZjYjhlYyJ9.0sTzfiTJ324NWAWMfk7RII4gFkOHCc8mdxHv01oEr0U","subscriptionTokens":{"main-channel":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjaGFubmVsIjoibWFpbi1jaGFubmVsIiwic3ViIjoiZmY0Njk0OGI2NzdjNDdmNzQyMTQ2NmQ1NTY2Y2I4ZWMifQ.QqaNbdZBucRuqBSeZvFp1AB-bO0pWxe_QrdYsEvIOfo"},"userRoles":"guest","userId":"ff46948b677c47f7421466d5566cb8ec"};</script>
# <header class="header">
# <div class="container">
# <nav class="navbar navbar-expand-lg">
# <a class="dreamjob-logo__wrapper order-0" href="/" title="Главная Dream Job">
# <img alt="Dream Job логотип" class="dreamjob-logo__icon" src="/i/logo/logo.svg"/>
# <img alt="Dream Job название компании" class="dreamjob-logo__name" src="/i/logo/brand.svg"/>
# </a>
# <a class="monthly-award-tag" data-event-click='{"event_id":4,"scenario":"employer_month","event_type":1}' data-event-show='{"event_id":3,"scenario":"employer_month","event_type":1}' href="/company-month">
# <img alt="" class="monthly-award-tag__logo" src="/images/icons/month-company/ears-of-wheat_sm.svg"/>
# <span class="monthly-award-tag__text">Компания месяца</span>
# </a>
# <div class="input-group mob_input md-form form-sm form-2 d-lg-none order-3" id="headerMobSearch">
# <button class="header__btn-close reset-button" data-action="toggleClass" data-class="open_inp" data-target="#headerMobSearch" type="button">
# <svg class="rc__tLLGP" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M20 0v20V0ZM0 20V0v20Zm8.116-3.823-5.469-5.47a.999.999 0 0 1 0-1.414l5.469-5.47a.5.5 0 0 1 .707 0l.354.354a.5.5 0 0 1 0 .707L4.811 9.25H17.5a.5.5 0 0 1 .5.5v.5a.5.5 0 0 1-.5.5H4.811l4.366 4.366a.5.5 0 0 1 0 .707l-.354.354a.5.5 0 0 1-.707 0Z" fill="#3460A4" fill-rule="evenodd"></path>
# </svg>
# </button>
# <form action="/site/search" class="tt__wrap" id="search_form_header" method="get"> <div class="tt-scrollable-menu"><input aria-label="Search" autocomplete="off" class="form-control input-field" data-input-action="ttInputHandlerTopSearch" data-krajee-typeahead="typeahead_3fe4d359" id="w0" name="query" placeholder="Введите название компании" type="text"/></div>
# <button class="header__button-find reset-button" data-reach-goal="search_companies_top_button" type="submit"></button>
# <div class="tt__clear" data-action="ttClear"></div>
# </form>
# </div>
# <a class="header-button header-button--search d-lg-none order-2" data-action="headerSearchOpen" href="javascript:void(0)" role="button" title="Поиск компаний"></a>
# <!--            <a href="-->
# <!--" class="order-2 header-button header-button--vacancies d-lg-none"-->
# <!--               title="Вакансии" data-action="gaPush"-->
# <!--               data-layer-push='{"event":"vacancies_name_click"}' data-reach-goal="vacancies_top_button_click"-->
# <!--               data-event-click='-->
# <!--'-->
# <!--            >-->
# <a class="order-2 header-button header-button--wallet d-lg-none" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary" title="Зарплаты">
# </a>
# <!-- --> <div aria-controls="navContent" aria-expanded="false" class="bt icon-bg-burger reset-button d-lg-none order-2 collapsed" data-target="#navContent" data-toggle="collapse" role="button"></div>
# <div class="collapse navbar-collapse order-3" id="navContent">
# <!--               <div style="flex: 1 0;" class="input-group md-form form-sm form-2 pl-0 header__search-form d-none d-lg-block">-->
# <!--                   <form method="get" class="tt__wrap" action="-->
# <!--">-->
# <!-- --> <!--                        <button class="header__button-find reset-button" type="submit" data-reach-goal="search_companies_top_button"></button>-->
# <!--                        <div class="tt__clear" data-action="ttClear"></div>-->
# <!--                    </form>-->
# <!--               </div>-->
# <div class="header__buttons">
# <!--                    <a class="monthly-award-tag">-->
# <!--                        <img class="monthly-award-tag__logo logo" src="/images/icons/recommendations/ears-of-wheat.svg" alt="">-->
# <!--                        <span class="monthly-award-tag__text text">Компания месяца</span>-->
# <!--                    </a>-->
# <a class="header-button header-button--search d-none d-lg-block" href="/#search">
#                                 Поиск
#                             </a>
# <a class="header-button header-button--vacancies d-none d-lg-block" data-action="gaPush" data-event-click='{"event_id":24,"scenario":"jb"}' href="/vakansii">
#                                 Вакансии
#                             </a>
# <a class="header-button header-button--wallet d-none d-lg-block" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary">
#                                 Зарплаты
#                             </a>
# <a class="header-button header-button--for-employer d-none d-lg-block" href="/page/employers">Работодателям</a>
# <a class="header-button header-button--user d-none d-lg-block" href="/site/login">Войти</a>
# <div class="mob_menu d-lg-none js-modile-menu">
# <div class="inner-menu">
# <div class="inner_block-menu">
# <ul>
# <li class="month-company__burger-menu-item">
# <a class="bt body2r bt--primary-link icon-bg-ears-of-wheat_rounding" data-event-click='{"event_id":6,"scenario":"employer_month"}' data-event-show='{"event_id":5,"scenario":"employer_month"}' href="/company-month">Компания месяца</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-vacancies" href="/vakansii">Вакансии</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-wallet" href="/salary">Зарплаты</a></li>
# <li><a class="bt body2r bt--primary-link icon-bg-bag" href="/page/employers">Работодателям</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-profile" href="/site/login">Вход в личный кабинет</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <main class="industries" data-industries="">
# <div data-pjax-container="" data-pjax-push-state="" data-pjax-replace-state="" data-pjax-timeout="0" id="data_pjax">
# <form action="/categories" data-pjax="" id="pjax_form" method="get">
# <input class="js_update_form" id="sort" name="sort" type="hidden" value="-reviews_count"/>
# <div class="container">
# <div class="row">
# <h1 class="industries__title col-md-6 col-lg-4">Все отрасли</h1>
# <div class="industries-top col-md-6 col-lg-8">
# <h2 class="h2 d-none d-md-block"> </h2>
# <div class="sort" data-sort="">
# <div class="sort__title _default" data-sort-title="">
# <div class="sort__title-header">Сортировать по</div>
# <span class="sort__title-value" data-sort-title-value="">количеству отзывов</span></div>
# <div class="sort__options">
# <div class="sort__option sort__option--reviews" data-sort-option="asc" data-sort-option-text="количеству отзывов" onclick="$('#sort').val('-reviews_count').change()">количеству отзывов</div>
# <div class="sort__option sort__option--rating" data-sort-option="desc" data-sort-option-text="рейтингу" onclick="$('#sort').val('-total_rating').change()">рейтингу</div>
# </div>
# </div>
# <div class="industries-btn-filters d-md-none" data-mobile-filters-open="">
# <div class="industries-btn-filters__label">Фильтр</div>
# <div class="industries-btn-filters__icon" data-js="filter-icon">
# <img alt="Фильтры" loading="lazy" src="/images/dest/icons/icon-filter.svg"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="industries-main">
# <div class="container">
# <div class="row">
# <div class="col-lg-4 col-md-6">
# <div class="composite-banner composite-banner--use-filter">
# <div class="composite-banner__blue-text">
#         Воспользуйтесь поиском по отрасли и сортировкой
#     </div>
# </div>
# <div class="industries-filters__wrap" data-mobile-filters="">
# <div class="industries-filters">
# <div class="mobile-filters__top d-md-none">
# <a class="mobile-filters__top-btn" href="/categories">Сбросить</a>
# <h3 class="mobile-filters__top-title">Фильтры</h3>
# <button class="mobile-filters__top-btn" data-mobile-filters-close="">Отмена</button>
# </div>
# <div class="industries-filters__body b-form">
# <div class="b-form__block">
# <h3 class="industries-filters__caption"><span>Выберите отрасль</span></h3>
# <ul class="industries-filters__list">
# <li class="b-form__radio">
# <input id="category_45" name="category_id" type="radio" value="45"/>
# <label class="b-form__radio_label industries-filters__label" for="category_45"><span class="b-form__radio_label_icon"></span>Автомобильный бизнес</label>
# </li>
# <li class="b-form__radio">
# <input id="category_64" name="category_id" type="radio" value="64"/>
# <label class="b-form__radio_label industries-filters__label" for="category_64"><span class="b-form__radio_label_icon"></span>Гостиницы, рестораны, общепит, кейтеринг</label>
# </li>
# <li class="b-form__radio">
# <input id="category_52" name="category_id" type="radio" value="52"/>
# <label class="b-form__radio_label industries-filters__label" for="category_52"><span class="b-form__radio_label_icon"></span>Государственные организации</label>
# </li>
# <li class="b-form__radio">
# <input id="category_59" name="category_id" type="radio" value="59"/>
# <label class="b-form__radio_label industries-filters__label" for="category_59"><span class="b-form__radio_label_icon"></span>Добывающая отрасль</label>
# </li>
# <li class="b-form__radio">
# <input id="category_65" name="category_id" type="radio" value="65"/>
# <label class="b-form__radio_label industries-filters__label" for="category_65"><span class="b-form__radio_label_icon"></span>ЖКХ</label>
# </li>
# <li class="b-form__radio">
# <input id="category_40" name="category_id" type="radio" value="40"/>
# <label class="b-form__radio_label industries-filters__label" for="category_40"><span class="b-form__radio_label_icon"></span>Информационные технологии, системная интеграция, интернет</label>
# </li>
# <li class="b-form__radio">
# <input id="category_66" name="category_id" type="radio" value="66"/>
# <label class="b-form__radio_label industries-filters__label" for="category_66"><span class="b-form__radio_label_icon"></span>Искусство, культура</label>
# </li>
# <li class="b-form__radio">
# <input id="category_46" name="category_id" type="radio" value="46"/>
# <label class="b-form__radio_label industries-filters__label" for="category_46"><span class="b-form__radio_label_icon"></span>Лесная промышленность, деревообработка</label>
# </li>
# <li class="b-form__radio">
# <input id="category_62" name="category_id" type="radio" value="62"/>
# <label class="b-form__radio_label industries-filters__label" for="category_62"><span class="b-form__radio_label_icon"></span>Медицина, фармацевтика, аптеки</label>
# </li>
# <li class="b-form__radio">
# <input id="category_47" name="category_id" type="radio" value="47"/>
# <label class="b-form__radio_label industries-filters__label" for="category_47"><span class="b-form__radio_label_icon"></span>Металлургия, металлообработка</label>
# </li>
# <li class="b-form__radio">
# <input id="category_61" name="category_id" type="radio" value="61"/>
# <label class="b-form__radio_label industries-filters__label" for="category_61"><span class="b-form__radio_label_icon"></span>Нефть и газ</label>
# </li>
# <li class="b-form__radio">
# <input id="category_54" name="category_id" type="radio" value="54"/>
# <label class="b-form__radio_label industries-filters__label" for="category_54"><span class="b-form__radio_label_icon"></span>Образовательные учреждения</label>
# </li>
# <li class="b-form__radio">
# <input id="category_53" name="category_id" type="radio" value="53"/>
# <label class="b-form__radio_label industries-filters__label" for="category_53"><span class="b-form__radio_label_icon"></span>Общественная деятельность, партии, благотворительность, НКО</label>
# </li>
# <li class="b-form__radio">
# <input id="category_39" name="category_id" type="radio" value="39"/>
# <label class="b-form__radio_label industries-filters__label" for="category_39"><span class="b-form__radio_label_icon"></span>Перевозки, логистика, склад, ВЭД</label>
# </li>
# <li class="b-form__radio">
# <input id="category_48" name="category_id" type="radio" value="48"/>
# <label class="b-form__radio_label industries-filters__label" for="category_48"><span class="b-form__radio_label_icon"></span>Продукты питания</label>
# </li>
# <li class="b-form__radio">
# <input id="category_67" name="category_id" type="radio" value="67"/>
# <label class="b-form__radio_label industries-filters__label" for="category_67"><span class="b-form__radio_label_icon"></span>Промышленное оборудование, техника, станки и комплектующие</label>
# </li>
# <li class="b-form__radio">
# <input id="category_55" name="category_id" type="radio" value="55"/>
# <label class="b-form__radio_label industries-filters__label" for="category_55"><span class="b-form__radio_label_icon"></span>Розничная торговля</label>
# </li>
# <li class="b-form__radio">
# <input id="category_49" name="category_id" type="radio" value="49"/>
# <label class="b-form__radio_label industries-filters__label" for="category_49"><span class="b-form__radio_label_icon"></span>Сельское хозяйство</label>
# </li>
# <li class="b-form__radio">
# <input id="category_43" name="category_id" type="radio" value="43"/>
# <label class="b-form__radio_label industries-filters__label" for="category_43"><span class="b-form__radio_label_icon"></span>СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование</label>
# </li>
# <li class="b-form__radio">
# <input id="category_44" name="category_id" type="radio" value="44"/>
# <label class="b-form__radio_label industries-filters__label" for="category_44"><span class="b-form__radio_label_icon"></span>Строительство, недвижимость, эксплуатация, проектирование</label>
# </li>
# <li class="b-form__radio">
# <input id="category_42" name="category_id" type="radio" value="42"/>
# <label class="b-form__radio_label industries-filters__label" for="category_42"><span class="b-form__radio_label_icon"></span>Телекоммуникации, связь</label>
# </li>
# <li class="b-form__radio">
# <input id="category_56" name="category_id" type="radio" value="56"/>
# <label class="b-form__radio_label industries-filters__label" for="category_56"><span class="b-form__radio_label_icon"></span>Товары народного потребления (непищевые)</label>
# </li>
# <li class="b-form__radio">
# <input id="category_50" name="category_id" type="radio" value="50"/>
# <label class="b-form__radio_label industries-filters__label" for="category_50"><span class="b-form__radio_label_icon"></span>Тяжелое машиностроение</label>
# </li>
# <li class="b-form__radio">
# <input id="category_68" name="category_id" type="radio" value="68"/>
# <label class="b-form__radio_label industries-filters__label" for="category_68"><span class="b-form__radio_label_icon"></span>Управление многопрофильными активами</label>
# </li>
# <li class="b-form__radio">
# <input id="category_58" name="category_id" type="radio" value="58"/>
# <label class="b-form__radio_label industries-filters__label" for="category_58"><span class="b-form__radio_label_icon"></span>Услуги для бизнеса</label>
# </li>
# <li class="b-form__radio">
# <input id="category_63" name="category_id" type="radio" value="63"/>
# <label class="b-form__radio_label industries-filters__label" for="category_63"><span class="b-form__radio_label_icon"></span>Услуги для населения</label>
# </li>
# <li class="b-form__radio">
# <input id="category_57" name="category_id" type="radio" value="57"/>
# <label class="b-form__radio_label industries-filters__label" for="category_57"><span class="b-form__radio_label_icon"></span>Финансовый сектор</label>
# </li>
# <li class="b-form__radio">
# <input id="category_51" name="category_id" type="radio" value="51"/>
# <label class="b-form__radio_label industries-filters__label" for="category_51"><span class="b-form__radio_label_icon"></span>Химическое производство, удобрения</label>
# </li>
# <li class="b-form__radio">
# <input id="category_41" name="category_id" type="radio" value="41"/>
# <label class="b-form__radio_label industries-filters__label" for="category_41"><span class="b-form__radio_label_icon"></span>Электроника, приборостроение, бытовая техника, компьютеры и оргтехника</label>
# </li>
# <li class="b-form__radio">
# <input id="category_60" name="category_id" type="radio" value="60"/>
# <label class="b-form__radio_label industries-filters__label" for="category_60"><span class="b-form__radio_label_icon"></span>Энергетика</label>
# </li>
# </ul>
# <input name="city" type="hidden" value=""/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-8 col-md-6 industries-body">
# <h2 class="industries-body__title d-md-none"> </h2>
# <div class="industries-body__content">
# <div class="industries-block" data-industries-block="">
# <div class="row industries-block__body" id="main_employer_div">
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26161,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26161,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26161">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26161/69171d4cd7cfacztMX4.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">МАГНИТ, Розничная сеть</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,4        <span class="sb-rating__stars" style="width:69.04px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">26 902 отзыва</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25583,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25583,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25583">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25583/67a06f1902c93KW9HrJ.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">СБЕР</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,0        <span class="sb-rating__stars" style="width:82.48px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">25 781 отзыв</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26066,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26066,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26066">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26066/67a06f4845578vBI8MB.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Российские железные дороги</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,7        <span class="sb-rating__stars" style="width:73.68px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">22 383 отзыва</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25607,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25607,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25607">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25607/67e2cc236b3b79brhr2.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Т-Банк</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,1        <span class="sb-rating__stars" style="width:82.96px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">16 881 отзыв</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26069,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26069,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26069">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26069/67a06f47d0658esPE1E.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Альфа-Банк</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,5        <span class="sb-rating__stars" style="width:89.2px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">15 717 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25930,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25930,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25930">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25930/67a06f3a2e91bwJ6GCM.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Банк ВТБ (ПАО)</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,2        <span class="sb-rating__stars" style="width:85.52px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">15 375 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26091,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26091,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26091">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26091/67a06f4a06a31V2UlNR.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Ростелеком</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,8        <span class="sb-rating__stars" style="width:74.64px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">15 136 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":6690,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":6690,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/6690">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/6690/6992c483b04d5XU9IXp.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">RWB (Wildberries &amp; Russ)</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,7        <span class="sb-rating__stars" style="width:73.52px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">14 478 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25947,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25947,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25947">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25947/67addfd466510E7rrc3.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">билайн</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,2        <span class="sb-rating__stars" style="width:85.68px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">14 090 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25946,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25946,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25946">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25946/67a06f3b4b268vLHfBX.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">МТС</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,1        <span class="sb-rating__stars" style="width:83.12px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">13 591 отзыв</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25921,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25921,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25921">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25921/67a06f3806a44wlxk_q.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Пятёрочка</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,6        <span class="sb-rating__stars" style="width:71.44px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">13 225 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":37011,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":37011,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/37011">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/37011/67a071e53158ch9glmW.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Красное &amp; Белое, розничная сеть</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,3        <span class="sb-rating__stars" style="width:67.44px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">11 381 отзыв</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":56818,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":56818,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/56818">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/56818/675c401bab623HPg3QH.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Почта России</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,1        <span class="sb-rating__stars" style="width:63.12px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">11 145 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26029,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26029,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26029">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26029/67da7738bc86crW-HZP.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Ozon</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,5        <span class="sb-rating__stars" style="width:90.32px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">11 034 отзыва</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25596,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25596,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25596">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25596/67a06f1a36b59uafKli.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Спортмастер</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,2        <span class="sb-rating__stars" style="width:85.52px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">10 290 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":46157,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":46157,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/46157">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/46157/67a07414a9510DFIOfE.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Совкомбанк</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,3        <span class="sb-rating__stars" style="width:86.48px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">8 567 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26028,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26028,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26028">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26028/67a06f440c780WIXoeJ.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Сеть магазинов цифровой и бытовой техники DNS</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,7        <span class="sb-rating__stars" style="width:73.52px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">7 033 отзыва</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26002,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26002,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26002">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26002/67a06f411f2e6wF6G34.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Лемана ПРО</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,0        <span class="sb-rating__stars" style="width:77.68px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">7 029 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":2672030,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":2672030,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/2672030">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/2672030/6761d1590d45a8BqC0N.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Яндекс Команда для бизнеса</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,5        <span class="sb-rating__stars" style="width:90.64px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">6 921 отзыв</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25924,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25924,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25924">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25924/67a06f3844a3cc71w68.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">М.Видео-Эльдорадо</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,9        <span class="sb-rating__stars" style="width:76.88px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">6 627 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26011,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":26011,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26011">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26011/67a06f4252f459PJJed.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Лента, федеральная розничная сеть</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,6        <span class="sb-rating__stars" style="width:70.8px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">6 529 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25879,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25879,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25879">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25879/67a06f329967ftGdCWj.webp');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Детский мир</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,5        <span class="sb-rating__stars" style="width:69.68px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">5 508 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25704,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":25704,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25704">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25704/68d0f45b92890PC5T1Q.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">FIX PRICE</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,9        <span class="sb-rating__stars" style="width:75.92px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">5 430 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":104847,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":104847,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/104847">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/104847/675c44e7620e4WGKsn5.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Вкусно — и точка</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,8        <span class="sb-rating__stars" style="width:74.8px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">5 350 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":56859,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":56859,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/56859">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/56859/697861af9b730ghG96q.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">ВкусВилл</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         4,2        <span class="sb-rating__stars" style="width:84.4px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">5 216 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25920,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# ...
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">ГЛОРИЯ ДЖИНС</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,7        <span class="sb-rating__stars" style="width:73.84px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">4 150 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":286960,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
# <a class="" data-event-click='{"employer_id":286960,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/286960">
# <div class="industry-card">
# <div class="industry-card__inner">
# <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png');">
# </div>
# <div class="industry-card__content">
# <div class="industry-card__name-wrap">
# <div class="industry-card__name line-clamp-3">Розничная сеть МТС</div>
# </div>
# <div class="sb-rating">
# <span class="sb-rating__value">
#         3,3        <span class="sb-rating__stars" style="width:66.96px;">-</span>
# </span>
# </div>
# <div class="industry-card__review-link">4 012 отзывов</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="industries-block__bottom">
# <a class="b-btn _blue industries-block__load-more" href="/categories?page=2&amp;per-page=36" id="show_more_news">Показать еще <span class="d-none d-md-block"></span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </form> </div></main>
# <footer class="footer">
# <div class="footer__container">
# <div class="footer__grid">
# <div class="footer__card">
# <a aria-controls="collapseOne" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseOne" id="headingOne" role="button">
#                     Соискателям
#                 </a>
# <div aria-labelledby="headingOne" class="footer__collapse collapse" id="collapseOne">
# <a class="footer__link footer__link_hover" href="/applicant2/reviews/index">
#                         Личный кабинет
#                     </a>
# <a class="footer__link footer__link_hover" href="/anonym">
#                         Гарантия анонимности
#                     </a>
# <a class="footer__link footer__link_hover" href="/salary">
#                         Зарплаты
#                     </a>
# <a class="footer__link footer__link_hover" href="/vakansii">
#                         Вакансии
#                     </a>
# <a class="footer__link footer__link_hover" href="/categories">
#                         Компании по категориям
#                     </a>
# <a class="footer__link footer__link_hover" href="/add">
#                         Оставить отзыв
#                     </a>
# </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseTwo" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseTwo" id="headingTwo" role="button">
#                     Работодателям
#                 </a>
# <div aria-labelledby="headingTwo" class="footer__collapse collapse" id="collapseTwo">
# <a class="footer__link footer__link_hover" data-reach-goal="click_employer_profile" href="/employer">
#                         Личный кабинет
#                     </a>
# <a class="footer__link footer__link_hover" data-reach-goal="click_platform_potential" href="/page/employers">
#                         Возможности платформы
#                     </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-copyright.pdf" target="_blank">
# <span>Гайд по копирайтингу</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-visual.pdf" target="_blank">
# <span>Гайд по брендингу</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-reviews-collect.pdf" target="_blank">
# <span>Гайд по сбору отзывов</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-widget.pdf" target="_blank">
# <span>Виджет на сайт</span>
# </a>
# <a class="footer__link footer__link_hover" href="/employers/258089/blog/apdejt-po-pilotu-korporativnyh-blogov-na-dream-job">
#                         Корпоративные блоги
#                     </a>
# <a class="footer__link footer__link_hover" data-reach-goal="click_add_company" href="/site/register?role=employer_admin">
#                             Добавить компанию
#                         </a>
# <form action="/site/show-hj" id="w1" method="post" target="_blank">
# <input name="_csrf" type="hidden" value="ApKOhP02V7cstxADrcbgMoKMBgNo8RY2NAEqmGuvvvh0y6PWqAA2wRz6VE3G8L945_V1Rx6AXQMCZxr6GPrymw=="/> <span class="footer__link footer__link_hover" onclick="$(this).closest('form').submit()">
#                             Dream Job + Happy Job
#                         </span>
# </form> </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseThree" aria-expanded="true" class="footer__title footer__title_border collapsed" data-toggle="collapse" href="#collapseThree" id="headingThree" role="button">
#                     О Dream Job
#                 </a>
# <div aria-labelledby="headingThree" class="footer__collapse footer__collapse_border collapse" id="collapseThree">
# <a class="footer__link footer__link_hover" href="/employers/258089/career#blockCareer">
#                         О проекте
#                     </a>
# <a class="footer__link footer__link_hover" href="/principles">
#                         Правила и принципы
#                     </a>
# <a class="footer__link footer__link_hover" href="/license-agreement">
#                         Пользовательское соглашение
#                     </a>
# <a class="footer__link footer__link_hover" href="/privacy">
#                         Политика конфиденциальности
#                     </a>
# <a class="footer__link footer__link_hover" href="/it-activity">
#                         Деятельность в IT-сфере
#                     </a>
# <a class="footer__link footer__link_hover" href="/article/software ">
#                         Реестр ПО РФ
#                     </a>
# <a class="footer__link footer__link_hover" data-event-click='{"event_id":350,"scenario":"lkr"}' href="/release-notes ">
#                         Что нового на Dream Job
#                     </a>
# </div>
# <a aria-controls="collapseFour" aria-expanded="true" class="footer__title mt-md-5 collapsed" data-toggle="collapse" href="#collapseFour" id="headingFour" role="button">
#                     Адрес
#                 </a>
# <div aria-labelledby="headingFour" class="footer__collapse collapse" id="collapseFour">
# <span class="footer__link">ООО «ДРИМ ДЖОБ»</span>
# <span class="footer__link">улица Искры, д. 17А, стр. 3,<br/> Москва, 129344, Россия</span>
# <span class="footer__link">ИНН 7707450945 <br/> ОГРН 1217700149590</span>
# </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseFive" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseFive" id="headingFive" role="button">
#                     Связаться с нами
#                 </a>
# <div aria-labelledby="headingFive" class="footer__collapse collapse" id="collapseFive">
# <a class="footer__link footer__link_hover" href="/contacts">Контакты / Пресс-центр</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/career#photoCompany">Команда</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/vakansii">Вакансии</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/blog">Блог Dream Job</a>
# </div>
# </div>
# <div class="footer__card footer__card_left">
# <a class="footer__title">
#                     Служба поддержки
#                 </a>
# <div class="footer__collapse">
# <span class="footer__link">График работы:</span>
# <span class="footer__link">Понедельник-пятница, <br/> с 9 до 18 по Москве.</span>
# <div>
# <span class="footer__link footer__link_mail">Для работодателей:</span>
# <a class="footer__mail" href="mailto:employers@dreamjob.ru">employers@dreamjob.ru</a>
# </div>
# <div>
# <span class="footer__link footer__link_mail">Для соискателей:</span>
# <a class="footer__mail" href="mailto:info@dreamjob.ru">info@dreamjob.ru</a>
# </div>
# <a class="footer__telegram" href="https://t.me/+-CLt0jp2KOUzOWIy" rel="nofollow noopener noreferrer" target="_blank" title="Dream Job в телеграмм">
#                         Мы в телеграм
#                     </a>
# </div>
# </div>
# </div>
# <div class="footer__info">
# <div class="footer-top">
# <p class="footer__text">Dream Job — крупнейший в России сайт отзывов сотрудников,
#                     нам доверяют более 7 000 000 пользователей ежемесячно.</p>
# <p class="footer__text">
#                     Миссия платформы — делать рынок труда в России прозрачнее и справедливее,
#                     помогать людям находить работу, а компаниям — становиться лучшими работодателями.
#                 </p>
# </div>
# <div class="footer-bottom">
# <p class="footer__text">
#                     Dream Job использует файлы cookie с целью безопасности, а также
#                     оптимизации и персонализации сервисов и повышения удобства пользования сайтом.
#                     Cookie представляют собой небольшие файлы, содержащие информацию о предыдущих посещениях сайта.
#                     Если вы не хотите использовать файлы cookie, измените настройки браузера.
#                 </p>
# <p class="footer__text">
#                     Свидетельство на товарный знак № 914157 от 09.01.2023 г
#                     <br/>
#                     © 2026. ООО "Дрим Джоб". Все права защищены.
#                 </p>
# </div>
# <div class="footer-middle">
# <!--dj rating-->
# <a href="https://dreamjob.ru/employers/258089" rel="noopener" target="_blank"><img alt="Dream Job отзывы сотрудников о работодателе на Dream Job" data-id="wg-258089-1-1" height="114" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg'%3E%3C/svg%3E" style="border:0" title="Рейтинг работодателя на Dream Job" width="170"/>
# </a>
# <script>(function (s) {
#                     document.querySelectorAll("[data-id=wg-258089-1-1]").forEach(function (e) {
#                       e.src = s
#                     })
#                   }("https://dreamjob.ru/widget/light?employer_id=258089"))</script>
# <!--/dj rating-->
# </div>
# </div>
# </div>
# </footer>
# <script src="/assets/5e8b9362/jquery.min.js?v=1693204750"></script>
# <script src="/assets/84fcf258/yii.js?v=1767968650"></script>
# <script src="/assets/10afff40/jquery-ui.min.js?v=1473979674"></script>
# <script src="/assets/a0ab202/js/bootstrap.bundle.min.js?v=1773644475"></script>
# <script src="/assets/75dc149a/js/typeahead.bundle.min.js?v=1559106416"></script>
# <script src="/assets/75dc149a/js/typeahead-kv.min.js?v=1559106416"></script>
# <script src="/assets/38b60184/js/kv-widgets.min.js?v=1654067138"></script>
# <script src="/js/dj_data_save.js?v=1773644461"></script>
# <script src="/js/loader.min.js?v=1775227568"></script>
# <script src="/js/app.min.js?v=1773644461"></script>
# <script src="/assets/84fcf258/yii.activeForm.js?v=1767968650"></script>
# <script src="/assets/93882470/jquery.pjax.js?v=1768915604"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/centrifuge/5.2.0/centrifuge.min.js"></script>
# <script src="/assets/c3ae0fcc/js/centrifuge.js?v=1773644461"></script>
# <script src="/js/set-focus-on-search.js?v=1773644461"></script>
# <script src="/js/mobile-header-logo-switcher.js?v=1773644461"></script>
# <script>jQuery(function ($) {
# jQuery('#pjax_form').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery(document).pjax("#data_pjax a", {"push":true,"replace":true,"timeout":0,"scrollTo":false,"container":"#data_pjax"});
# jQuery(document).off("submit", "#data_pjax form[data-pjax]").on("submit", "#data_pjax form[data-pjax]", function (event) {jQuery.pjax.submit(event, {"push":true,"replace":true,"timeout":0,"scrollTo":false,"container":"#data_pjax"});});
#
#
#     ((filter) => {
#         filter.submitForm = () => {
#             $.ajax({
#                 url: '/site/create-category-filter-form-action',
#                 data: new FormData(filter.getJQForm().get(0)),
#                 processData: false,
#                 contentType: false,
#                 type: 'POST',
#                 success: (data) => {
#                     if (filter.getCategoryInput()) {
#                         filter.getCategoryInput().disabled = true;
#                     }
#
#                     filter.getCityInput().disabled = true;
#
#                     filter.getJQForm().attr('action', data).submit();
#
#                     if (filter.getCategoryInput()) {
#                         filter.getCategoryInput().disabled = false;
#                     }
#
#                     filter.getCityInput().disabled = false;
#                 }
#             });
#         };
#
#         $(document).on('change', '#pjax_form input,select', () => {
#             $('._open-mobile-filters').css('overflow', 'scroll');
#             filter.submitForm();
#         });
#
#         $(document).on('pjax:end', '#data_pjax_more' ,function(){
#             let new_div = $(this).find('.industries-block__body');
#             let html = new_div.html();
#             new_div.remove();
#             $(html).appendTo('#main_employer_div');
#         });
#
#         $(document).on('pjax:end', function() {
#
#             var checkedFiltersAmount = $('input:checked', $('#pjax_form')).length;
#
#             if (checkedFiltersAmount === 0) {
#                 $('span', filter.getJQFilterIcon()).remove();
#             } else {
#                 filter.getJQFilterIcon().append('<span>' + checkedFiltersAmount + '</span>');
#             }
#
#             if (filter.getCategoryInput()) {
#                 filter.getCategoryInput().disabled = false;
#             }
#
#             filter.getCityInput().disabled = false;
#             filter.getSortInput().disabled = false;
#
#         });
#
#         $(document).on('click', '[type=reset]', () => {
#             if (filter.getCategoryInput()) {
#                 filter.getCategoryInput().checked = false;
#             }
#
#             filter.getCityInput().disabled = true;
#             filter.getSortInput().disabled = true;
#
#             filter.submitForm();
#
#             filter.getSortInput().disabled = false;
#         });
#
#     })({
#         getCategoryInput: () => document.querySelector('[name="category_id"]:checked'),
#         getCityInput: () => document.querySelector('[name="city"]'),
#         getSortInput: () => document.querySelector('[name="sort"]'),
#         getJQFilterIcon: () => $('[data-js="filter-icon"]'),
#         getJQForm: () => $('#pjax_form')
#     });
#
#     $(document).on('click', '#show_more_news', () => { window.scrollTo( {top: Math.round($('#pjax_form').offset().top), behavior: 'smooth'} ) })
#
#
# jQuery&&jQuery.pjax&&(jQuery.pjax.defaults.maxCacheLength=0);
# var w0_data_1 = new Bloodhound({"datumTokenizer":Bloodhound.tokenizers.obj.whitespace('value'),"queryTokenizer":Bloodhound.tokenizers.whitespace,"remote":{"url":"/ajax/search-employer?q=%QUERY","wildcard":"%QUERY"}});
# kvInitTA('w0', typeahead_3fe4d359, [{"display":"value","limit":10,"templates":{"suggestion":(o) => (`<p data-reach-goal="search_companies_top_list">${o.text}</p>`)},"name":"w0_data_1","source":w0_data_1.ttAdapter()}]);
# jQuery("#w0").on('typeahead:select', window.dj.actions.companySearchSuggestClick);
# jQuery("#w0").on('typeahead:render', window.dj.actions.companySearchTypeaheadRender);
# jQuery("#w0").on('typeahead:asyncrequest', window.dj.actions.ttLoadingHandler);
# jQuery("#w0").on('typeahead:asynccancel', window.dj.actions.ttLoadingHandler);
# jQuery("#w0").on('typeahead:asyncreceive', window.dj.actions.ttLoadingHandler);
# jQuery('#search_form_header').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery('#w1').yiiActiveForm([], []);
# });</script> <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-26e44a76514b85cdf44","applicationID":"1111264889","transactionName":"YFxVZEUCCEVQBU1YXVkWdlNDCglYHhVQRVcYWlZEUgQJRFgDSg==","queueTime":1,"applicationTime":48,"atts":"TBtWEg0YG0s=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1134516852",accountID:"4709628",trustKey:"4709628",xpid:"UAEHWFBRABABVVBTBQcDXlwI",licenseKey:"NRJS-26e44a76514b85cdf44",applicationID:"1111264889",browserID:"1134516852"};;/*! For license information please see nr-loader-spa-1.312.1.min.js.LICENSE.txt */
# (()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,Zm:()=>c,bQ:()=>u,dV:()=>d,pV:()=>l});var n=r(6154),i=r(1863),s=r(944),o=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function c(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function d(){let e=c();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,o.i)(...Object.values(e.o))),e}function u(e,t){let r=c();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t,2===Object.keys(r.initializedAgents).length&&(0,s.R)(69)}function l(){return function(){let e=c();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=c();const t=e.init||{};e.init={...t}}(),d(),function(){let e=c();const t=e.loader_config||{};e.loader_config={...t}}(),c()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>a,df:()=>s,qY:()=>n,v4:()=>o});const n="events",i="jserrors",s="browser/blobs",o="rum",a="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.softNav]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.sessionReplay]:8,[c.logging]:9,[c.genericEvents]:10},u={[c.pageViewEvent]:o,[c.pageViewTiming]:n,[c.ajax]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:a,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>o,TZ:()=>a,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},o="log",a=n.K7.logging},1541:(e,t,r)=>{"use strict";r.d(t,{$5:()=>d,B5:()=>c,Ux:()=>o,YA:()=>a,fQ:()=>i});var n=r(5871);const i={MFE:"MFE",BA:"BA"};function s(e,t){if(!e||!t?.init.api.allow_registered_children)return[];const r=t.runtime.registeredEntities;return r?.filter(t=>t.metadata.timings?.asset?.endsWith(e)).map(e=>e.metadata.target)||[]}function o(e,t){if(!u(t))return{};const r=t.agentRef.runtime.appMetadata.agents[0].entityGuid;return e?e.attributes:{"entity.guid":r,appId:t.agentRef.info.applicationID}}function a(e,t){return c(e,t)?{"child.id":e.id,"child.type":e.type,...o(void 0,t)}:{}}function c(e,t){return!!e&&!!u(t)&&t.agentRef.init.api.duplicate_registered_data}function d(e){if(!e?.init.api.allow_registered_children)return[void 0];const t=[];try{var r=(0,n.AZ)((0,n.QL)());let i=r.length-1;for(;r[i];)t.push(...s(r[i--],e))}catch(e){}return t.length||t.push(void 0),t}function u(e){return 2===e?.harvestEndpointVersion}},1687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>a,Ze:()=>d,x3:()=>c});var n=r(3241),i=r(3606),s=r(860),o=r(2646);function a(e,t){if(!e)return;const r={staged:!1,priority:s.P3[t]||0};e.runtime.drainRegistry.get(t)||e.runtime.drainRegistry.set(t,r)}function c(e,t){if(!e)return;const r=e.runtime.drainRegistry;r&&(r.get(t)&&r.delete(t),l(e,t,!1),r.size&&u(e))}function d(e,t="feature",r=!1){if(e){if(!e.runtime.drainRegistry.get(t)||r)return l(e,t);e.runtime.drainRegistry.get(t).staged=!0,u(e)}}function u(e){if(!e)return;const t=Array.from(e.runtime.drainRegistry);t.every(([e,t])=>t.staged)&&(t.so ...
#   </script>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <title>
#    Каталог предприятий, компаний России по сферам деятельности | Dream Job
#   </title>
#   <meta content="https://dreamjob.ru/categories" property="og:url"/>
#   <meta content="https://dreamjob.ru/i/dream-job.png" property="og:image"/>
#   <meta content="Dream Job - крупнейший ресурс с отзывами сотрудников в России" property="og:image:alt"/>
#   <meta content="image/png" property="og:image:type"/>
#   <meta content="1600" property="og:image:width"/>
#   <meta content="800" property="og:image:height"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Самый полный каталог предприятий, компаний России по сферам деятельности. Узнайте информацию о лидерах отрасли, просмотрите оценки, почитайте отзывы сотрудников — вся необходимая информация в одном месте Dream Job" name="description"/>
#   <link href="https://dreamjob.ru/categories" rel="canonical"/>
#   <link href="/assets/10afff40/themes/smoothness/jquery-ui.min.css?v=1473979674" rel="stylesheet"/>
#   <link href="/css/bs-4.6.1-dj.min.css?v=1773644459" rel="stylesheet"/>
#   <link href="/assets/75dc149a/css/typeahead.min.css?v=1559106416" rel="stylesheet"/>
#   <link href="/assets/75dc149a/css/typeahead-kv.min.css?v=1559106416" rel="stylesheet"/>
#   <link href="/assets/38b60184/css/kv-widgets.min.css?v=1654067138" rel="stylesheet"/>
#   <link href="/css/roboto_font.min.css?v=1773644459" rel="stylesheet"/>
#   <link href="/css/general-styles.min.css?v=1773644459" rel="stylesheet"/>
#   <link href="/css/header-main.min.css?v=1773644459" rel="stylesheet"/>
#   <link href="/css/dj/pages/categories.min.css?v=1773644459" rel="stylesheet"/>
#   <link href="/assets/c3ae0fcc/css/centrifuge.css?v=1773644461" rel="stylesheet"/>
#   <script>
#    window.typeahead_3fe4d359 = {"highlight":true,"minLength":2};
#   </script>
#   <script src="/js/fp_2_0_6.min.js">
#   </script>
#   <script>
#    Fingerprint2.get(function (cs) {
#         (function (w, d, s, l, i, c, fp, u, e, h) {
#             w[l] = w[l] || [];
#             w['fingerprint'] = {cs: cs, id: fp, uid: u, eid: e, hid: h};
#             w[l].push({fingerprint: fp});
#             if (u) w[l].push({user_id: u});
#             if (e) w[l].push({employer_id: e});
#             w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             try {
#                 c = JSON.parse(c);
#                 for (let p of Object.keys(c)) {
#                     w[l].push({event: 'FlagAssigned', 'flag_id': p, 'flag_is_on': c[p]});
#                 }
#             } catch (e) {
#             }
#                         /* Google Tag Manager */
#
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#             /* End Google Tag Manager */
#                     })(window, document, 'script', 'dataLayer', 'GTM-M3XGKC6', '',
#             Fingerprint2.x64hash128(cs.map(function (pair) {
#                 return pair.value
#             }).join(), 31), 0);
#     });
#   </script>
#   <meta content="_csrf" name="csrf-param"/>
#   <meta content="ApKOhP02V7cstxADrcbgMoKMBgNo8RY2NAEqmGuvvvh0y6PWqAA2wRz6VE3G8L945_V1Rx6AXQMCZxr6GPrymw==" name="csrf-token"/>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3XGKC6" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script>
#    var centrifugoOptions = {"wsConnectionEndpoint":"wss:\/\/centrifugo.dreamjob.ru:443\/connection\/websocket","connectionToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmZjQ2OTQ4YjY3N2M0N2Y3NDIxNDY2ZDU1NjZjYjhlYyJ9.0sTzfiTJ324NWAWMfk7RII4gFkOHCc8mdxHv01oEr0U","subscriptionTokens":{"main-channel":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjaGFubmVsIjoibWFpbi1jaGFubmVsIiwic3ViIjoiZmY0Njk0OGI2NzdjNDdmNzQyMTQ2NmQ1NTY2Y2I4ZWMifQ.QqaNbdZBucRuqBSeZvFp1AB-bO0pWxe_QrdYsEvIOfo"},"userRoles":"guest","userId":"ff46948b677c47f7421466d5566cb8ec"};
#   </script>
#   <header class="header">
#    <div class="container">
#     <nav class="navbar navbar-expand-lg">
#      <a class="dreamjob-logo__wrapper order-0" href="/" title="Главная Dream Job">
#       <img alt="Dream Job логотип" class="dreamjob-logo__icon" src="/i/logo/logo.svg"/>
#       <img alt="Dream Job название компании" class="dreamjob-logo__name" src="/i/logo/brand.svg"/>
#      </a>
#      <a class="monthly-award-tag" data-event-click='{"event_id":4,"scenario":"employer_month","event_type":1}' data-event-show='{"event_id":3,"scenario":"employer_month","event_type":1}' href="/company-month">
#       <img alt="" class="monthly-award-tag__logo" src="/images/icons/month-company/ears-of-wheat_sm.svg"/>
#       <span class="monthly-award-tag__text">
#        Компания месяца
#       </span>
#      </a>
#      <div class="input-group mob_input md-form form-sm form-2 d-lg-none order-3" id="headerMobSearch">
#       <button class="header__btn-close reset-button" data-action="toggleClass" data-class="open_inp" data-target="#headerMobSearch" type="button">
#        <svg class="rc__tLLGP" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#         <path clip-rule="evenodd" d="M20 0v20V0ZM0 20V0v20Zm8.116-3.823-5.469-5.47a.999.999 0 0 1 0-1.414l5.469-5.47a.5.5 0 0 1 .707 0l.354.354a.5.5 0 0 1 0 .707L4.811 9.25H17.5a.5.5 0 0 1 .5.5v.5a.5.5 0 0 1-.5.5H4.811l4.366 4.366a.5.5 0 0 1 0 .707l-.354.354a.5.5 0 0 1-.707 0Z" fill="#3460A4" fill-rule="evenodd">
#         </path>
#        </svg>
#       </button>
#       <form action="/site/search" class="tt__wrap" id="search_form_header" method="get">
#        <div class="tt-scrollable-menu">
#         <input aria-label="Search" autocomplete="off" class="form-control input-field" data-input-action="ttInputHandlerTopSearch" data-krajee-typeahead="typeahead_3fe4d359" id="w0" name="query" placeholder="Введите название компании" type="text"/>
#        </div>
#        <button class="header__button-find reset-button" data-reach-goal="search_companies_top_button" type="submit">
#        </button>
#        <div class="tt__clear" data-action="ttClear">
#        </div>
#       </form>
#      </div>
#      <a class="header-button header-button--search d-lg-none order-2" data-action="headerSearchOpen" href="javascript:void(0)" role="button" title="Поиск компаний">
#      </a>
#      <!--            <a href="-->
#      <!--" class="order-2 header-button header-button--vacancies d-lg-none"-->
#      <!--               title="Вакансии" data-action="gaPush"-->
#      <!--               data-layer-push='{"event":"vacancies_name_click"}' data-reach-goal="vacancies_top_button_click"-->
#      <!--               data-event-click='-->
#      <!--'-->
#      <!--            >-->
#      <a class="order-2 header-button header-button--wallet d-lg-none" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary" title="Зарплаты">
#      </a>
#      <!-- -->
#      <div aria-controls="navContent" aria-expanded="false" class="bt icon-bg-burger reset-button d-lg-none order-2 collapsed" data-target="#navContent" data-toggle="collapse" role="button">
#      </div>
#      <div class="collapse navbar-collapse order-3" id="navContent">
#       <!--               <div style="flex: 1 0;" class="input-group md-form form-sm form-2 pl-0 header__search-form d-none d-lg-block">-->
#       <!--                   <form method="get" class="tt__wrap" action="-->
#       <!--">-->
#       <!-- -->
#       <!--                        <button class="header__button-find reset-button" type="submit" data-reach-goal="search_companies_top_button"></button>-->
#       <!--                        <div class="tt__clear" data-action="ttClear"></div>-->
#       <!--                    </form>-->
#       <!--               </div>-->
#       <div class="header__buttons">
#        <!--                    <a class="monthly-award-tag">-->
#        <!--                        <img class="monthly-award-tag__logo logo" src="/images/icons/recommendations/ears-of-wheat.svg" alt="">-->
#        <!--                        <span class="monthly-award-tag__text text">Компания месяца</span>-->
#        <!--                    </a>-->
#        <a class="header-button header-button--search d-none d-lg-block" href="/#search">
#         Поиск
#        </a>
#        <a class="header-button header-button--vacancies d-none d-lg-block" data-action="gaPush" data-event-click='{"event_id":24,"scenario":"jb"}' href="/vakansii">
#         Вакансии
#        </a>
#        <a class="header-button header-button--wallet d-none d-lg-block" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary">
#         Зарплаты
#        </a>
#        <a class="header-button header-button--for-employer d-none d-lg-block" href="/page/employers">
#         Работодателям
#        </a>
#        <a class="header-button header-button--user d-none d-lg-block" href="/site/login">
#         Войти
#        </a>
#        <div class="mob_menu d-lg-none js-modile-menu">
#         <div class="inner-menu">
#          <div class="inner_block-menu">
#           <ul>
#            <li class="month-company__burger-menu-item">
#             <a class="bt body2r bt--primary-link icon-bg-ears-of-wheat_rounding" data-event-click='{"event_id":6,"scenario":"employer_month"}' data-event-show='{"event_id":5,"scenario":"employer_month"}' href="/company-month">
#              Компания месяца
#             </a>
#            </li>
#            <li>
#             <a class="bt body2r bt--primary-link icon-bg-vacancies" href="/vakansii">
#              Вакансии
#             </a>
#            </li>
#            <li>
#             <a class="bt body2r bt--primary-link icon-bg-wallet" href="/salary">
#              Зарплаты
#             </a>
#            </li>
#            <li>
#             <a class="bt body2r bt--primary-link icon-bg-bag" href="/page/employers">
#              Работодателям
#             </a>
#            </li>
#            <li>
#             <a class="bt body2r bt--primary-link icon-bg-profile" href="/site/login">
#              Вход в личный кабинет
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </header>
#   <main class="industries" data-industries="">
#    <div data-pjax-container="" data-pjax-push-state="" data-pjax-replace-state="" data-pjax-timeout="0" id="data_pjax">
#     <form action="/categories" data-pjax="" id="pjax_form" method="get">
#      <input class="js_update_form" id="sort" name="sort" type="hidden" value="-reviews_count"/>
#      <div class="container">
#       <div class="row">
#        <h1 class="industries__title col-md-6 col-lg-4">
#         Все отрасли
#        </h1>
#        <div class="industries-top col-md-6 col-lg-8">
#         <h2 class="h2 d-none d-md-block">
#         </h2>
#         <div class="sort" data-sort="">
#          <div class="sort__title _default" data-sort-title="">
#           <div class="sort__title-header">
#            Сортировать по
#           </div>
#           <span class="sort__title-value" data-sort-title-value="">
#            количеству отзывов
#           </span>
#          </div>
#          <div class="sort__options">
#           <div class="sort__option sort__option--reviews" data-sort-option="asc" data-sort-option-text="количеству отзывов" onclick="$('#sort').val('-reviews_count').change()">
#            количеству отзывов
#           </div>
#           <div class="sort__option sort__option--rating" data-sort-option="desc" data-sort-option-text="рейтингу" onclick="$('#sort').val('-total_rating').change()">
#            рейтингу
#           </div>
#          </div>
#         </div>
#         <div class="industries-btn-filters d-md-none" data-mobile-filters-open="">
#          <div class="industries-btn-filters__label">
#           Фильтр
#          </div>
#          <div class="industries-btn-filters__icon" data-js="filter-icon">
#           <img alt="Фильтры" loading="lazy" src="/images/dest/icons/icon-filter.svg"/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <section class="industries-main">
#       <div class="container">
#        <div class="row">
#         <div class="col-lg-4 col-md-6">
#          <div class="composite-banner composite-banner--use-filter">
#           <div class="composite-banner__blue-text">
#            Воспользуйтесь поиском по отрасли и сортировкой
#           </div>
#          </div>
#          <div class="industries-filters__wrap" data-mobile-filters="">
#           <div class="industries-filters">
#            <div class="mobile-filters__top d-md-none">
#             <a class="mobile-filters__top-btn" href="/categories">
#              Сбросить
#             </a>
#             <h3 class="mobile-filters__top-title">
#              Фильтры
#             </h3>
#             <button class="mobile-filters__top-btn" data-mobile-filters-close="">
#              Отмена
#             </button>
#            </div>
#            <div class="industries-filters__body b-form">
#             <div class="b-form__block">
#              <h3 class="industries-filters__caption">
#               <span>
#                Выберите отрасль
#               </span>
#              </h3>
#              <ul class="industries-filters__list">
#               <li class="b-form__radio">
#                <input id="category_45" name="category_id" type="radio" value="45"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_45">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Автомобильный бизнес
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_64" name="category_id" type="radio" value="64"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_64">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Гостиницы, рестораны, общепит, кейтеринг
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_52" name="category_id" type="radio" value="52"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_52">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Государственные организации
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_59" name="category_id" type="radio" value="59"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_59">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Добывающая отрасль
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_65" name="category_id" type="radio" value="65"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_65">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 ЖКХ
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_40" name="category_id" type="radio" value="40"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_40">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Информационные технологии, системная интеграция, интернет
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_66" name="category_id" type="radio" value="66"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_66">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Искусство, культура
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_46" name="category_id" type="radio" value="46"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_46">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Лесная промышленность, деревообработка
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_62" name="category_id" type="radio" value="62"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_62">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Медицина, фармацевтика, аптеки
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_47" name="category_id" type="radio" value="47"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_47">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Металлургия, металлообработка
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_61" name="category_id" type="radio" value="61"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_61">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Нефть и газ
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_54" name="category_id" type="radio" value="54"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_54">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Образовательные учреждения
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_53" name="category_id" type="radio" value="53"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_53">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Общественная деятельность, партии, благотворительность, НКО
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_39" name="category_id" type="radio" value="39"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_39">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Перевозки, логистика, склад, ВЭД
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_48" name="category_id" type="radio" value="48"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_48">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Продукты питания
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_67" name="category_id" type="radio" value="67"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_67">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Промышленное оборудование, техника, станки и комплектующие
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_55" name="category_id" type="radio" value="55"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_55">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Розничная торговля
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_49" name="category_id" type="radio" value="49"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_49">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Сельское хозяйство
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_43" name="category_id" type="radio" value="43"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_43">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_44" name="category_id" type="radio" value="44"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_44">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Строительство, недвижимость, эксплуатация, проектирование
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_42" name="category_id" type="radio" value="42"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_42">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Телекоммуникации, связь
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_56" name="category_id" type="radio" value="56"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_56">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Товары народного потребления (непищевые)
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_50" name="category_id" type="radio" value="50"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_50">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Тяжелое машиностроение
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_68" name="category_id" type="radio" value="68"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_68">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Управление многопрофильными активами
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_58" name="category_id" type="radio" value="58"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_58">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Услуги для бизнеса
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_63" name="category_id" type="radio" value="63"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_63">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Услуги для населения
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_57" name="category_id" type="radio" value="57"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_57">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Финансовый сектор
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_51" name="category_id" type="radio" value="51"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_51">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Химическое производство, удобрения
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_41" name="category_id" type="radio" value="41"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_41">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Электроника, приборостроение, бытовая техника, компьютеры и оргтехника
#                </label>
#               </li>
#               <li class="b-form__radio">
#                <input id="category_60" name="category_id" type="radio" value="60"/>
#                <label class="b-form__radio_label industries-filters__label" for="category_60">
#                 <span class="b-form__radio_label_icon">
#                 </span>
#                 Энергетика
#                </label>
#               </li>
#              </ul>
#              <input name="city" type="hidden" value=""/>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="col-lg-8 col-md-6 industries-body">
#          <h2 class="industries-body__title d-md-none">
#          </h2>
#          <div class="industries-body__content">
#           <div class="industries-block" data-industries-block="">
#            <div class="row industries-block__body" id="main_employer_div">
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26161,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":26161,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26161">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26161/69171d4cd7cfacztMX4.png');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    МАГНИТ, Розничная сеть
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,4
#                    <span class="sb-rating__stars" style="width:69.04px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   26 902 отзыва
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25583,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25583,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25583">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25583/67a06f1902c93KW9HrJ.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    СБЕР
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,0
#                    <span class="sb-rating__stars" style="width:82.48px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   25 781 отзыв
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26066,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":26066,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26066">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26066/67a06f4845578vBI8MB.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Российские железные дороги
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,7
#                    <span class="sb-rating__stars" style="width:73.68px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   22 383 отзыва
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25607,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25607,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25607">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25607/67e2cc236b3b79brhr2.png');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Т-Банк
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,1
#                    <span class="sb-rating__stars" style="width:82.96px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   16 881 отзыв
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26069,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":26069,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26069">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26069/67a06f47d0658esPE1E.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Альфа-Банк
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,5
#                    <span class="sb-rating__stars" style="width:89.2px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   15 717 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25930,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25930,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25930">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25930/67a06f3a2e91bwJ6GCM.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Банк ВТБ (ПАО)
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,2
#                    <span class="sb-rating__stars" style="width:85.52px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   15 375 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":26091,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":26091,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/26091">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/26091/67a06f4a06a31V2UlNR.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Ростелеком
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,8
#                    <span class="sb-rating__stars" style="width:74.64px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   15 136 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":6690,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":6690,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/6690">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/6690/6992c483b04d5XU9IXp.png');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    RWB (Wildberries &amp; Russ)
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,7
#                    <span class="sb-rating__stars" style="width:73.52px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   14 478 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25947,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25947,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25947">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25947/67addfd466510E7rrc3.png');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    билайн
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,2
#                    <span class="sb-rating__stars" style="width:85.68px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   14 090 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25946,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25946,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25946">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25946/67a06f3b4b268vLHfBX.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    МТС
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    4,1
#                    <span class="sb-rating__stars" style="width:83.12px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   13 591 отзыв
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":25921,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":25921,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/25921">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/25921/67a06f3806a44wlxk_q.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Пятёрочка
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,6
#                    <span class="sb-rating__stars" style="width:71.44px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   13 225 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":37011,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":37011,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/37011">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/37011/67a071e53158ch9glmW.webp');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Красное &amp; Белое, розничная сеть
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,3
#                    <span class="sb-rating__stars" style="width:67.44px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   11 381 отзыв
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="col-xl-3 col-lg-4 col-6 col-xl-3 industries-block__card" data-event-show='{"employer_id":56818,"batchSend":true,"scenario":"brand","event_id":13,"event_type":2}'>
#              <a class="" data-event-click='{"employer_id":56818,"scenario":"brand","event_id":14,"event_type":1}' data-pjax="0" href="/employers/56818">
#               <div class="industry-card">
#                <div class="industry-card__inner">
#                 <div class="industry-card__logo" style="background-image: url('https://cdn.dreamjob.ru/employer/56818/675c401bab623HPg3QH.png');">
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Почта России
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,1
#                    <span class="sb-rating__stars" style="width:63.12px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   11 145 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
# ...
#                 </div>
#                 <div class="industry-card__content">
#                  <div class="industry-card__name-wrap">
#                   <div class="industry-card__name line-clamp-3">
#                    Розничная сеть МТС
#                   </div>
#                  </div>
#                  <div class="sb-rating">
#                   <span class="sb-rating__value">
#                    3,3
#                    <span class="sb-rating__stars" style="width:66.96px;">
#                     -
#                    </span>
#                   </span>
#                  </div>
#                  <div class="industry-card__review-link">
#                   4 012 отзывов
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="industries-block__bottom">
#             <a class="b-btn _blue industries-block__load-more" href="/categories?page=2&amp;per-page=36" id="show_more_news">
#              Показать еще
#              <span class="d-none d-md-block">
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </form>
#    </div>
#   </main>
#   <footer class="footer">
#    <div class="footer__container">
#     <div class="footer__grid">
#      <div class="footer__card">
#       <a aria-controls="collapseOne" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseOne" id="headingOne" role="button">
#        Соискателям
#       </a>
#       <div aria-labelledby="headingOne" class="footer__collapse collapse" id="collapseOne">
#        <a class="footer__link footer__link_hover" href="/applicant2/reviews/index">
#         Личный кабинет
#        </a>
#        <a class="footer__link footer__link_hover" href="/anonym">
#         Гарантия анонимности
#        </a>
#        <a class="footer__link footer__link_hover" href="/salary">
#         Зарплаты
#        </a>
#        <a class="footer__link footer__link_hover" href="/vakansii">
#         Вакансии
#        </a>
#        <a class="footer__link footer__link_hover" href="/categories">
#         Компании по категориям
#        </a>
#        <a class="footer__link footer__link_hover" href="/add">
#         Оставить отзыв
#        </a>
#       </div>
#      </div>
#      <div class="footer__card">
#       <a aria-controls="collapseTwo" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseTwo" id="headingTwo" role="button">
#        Работодателям
#       </a>
#       <div aria-labelledby="headingTwo" class="footer__collapse collapse" id="collapseTwo">
#        <a class="footer__link footer__link_hover" data-reach-goal="click_employer_profile" href="/employer">
#         Личный кабинет
#        </a>
#        <a class="footer__link footer__link_hover" data-reach-goal="click_platform_potential" href="/page/employers">
#         Возможности платформы
#        </a>
#        <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-copyright.pdf" target="_blank">
#         <span>
#          Гайд по копирайтингу
#         </span>
#        </a>
#        <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-visual.pdf" target="_blank">
#         <span>
#          Гайд по брендингу
#         </span>
#        </a>
#        <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-reviews-collect.pdf" target="_blank">
#         <span>
#          Гайд по сбору отзывов
#         </span>
#        </a>
#        <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-widget.pdf" target="_blank">
#         <span>
#          Виджет на сайт
#         </span>
#        </a>
#        <a class="footer__link footer__link_hover" href="/employers/258089/blog/apdejt-po-pilotu-korporativnyh-blogov-na-dream-job">
#         Корпоративные блоги
#        </a>
#        <a class="footer__link footer__link_hover" data-reach-goal="click_add_company" href="/site/register?role=employer_admin">
#         Добавить компанию
#        </a>
#        <form action="/site/show-hj" id="w1" method="post" target="_blank">
#         <input name="_csrf" type="hidden" value="ApKOhP02V7cstxADrcbgMoKMBgNo8RY2NAEqmGuvvvh0y6PWqAA2wRz6VE3G8L945_V1Rx6AXQMCZxr6GPrymw=="/>
#         <span class="footer__link footer__link_hover" onclick="$(this).closest('form').submit()">
#          Dream Job + Happy Job
#         </span>
#        </form>
#       </div>
#      </div>
#      <div class="footer__card">
#       <a aria-controls="collapseThree" aria-expanded="true" class="footer__title footer__title_border collapsed" data-toggle="collapse" href="#collapseThree" id="headingThree" role="button">
#        О Dream Job
#       </a>
#       <div aria-labelledby="headingThree" class="footer__collapse footer__collapse_border collapse" id="collapseThree">
#        <a class="footer__link footer__link_hover" href="/employers/258089/career#blockCareer">
#         О проекте
#        </a>
#        <a class="footer__link footer__link_hover" href="/principles">
#         Правила и принципы
#        </a>
#        <a class="footer__link footer__link_hover" href="/license-agreement">
#         Пользовательское соглашение
#        </a>
#        <a class="footer__link footer__link_hover" href="/privacy">
#         Политика конфиденциальности
#        </a>
#        <a class="footer__link footer__link_hover" href="/it-activity">
#         Деятельность в IT-сфере
#        </a>
#        <a class="footer__link footer__link_hover" href="/article/software ">
#         Реестр ПО РФ
#        </a>
#        <a class="footer__link footer__link_hover" data-event-click='{"event_id":350,"scenario":"lkr"}' href="/release-notes ">
#         Что нового на Dream Job
#        </a>
#       </div>
#       <a aria-controls="collapseFour" aria-expanded="true" class="footer__title mt-md-5 collapsed" data-toggle="collapse" href="#collapseFour" id="headingFour" role="button">
#        Адрес
#       </a>
#       <div aria-labelledby="headingFour" class="footer__collapse collapse" id="collapseFour">
#        <span class="footer__link">
#         ООО «ДРИМ ДЖОБ»
#        </span>
#        <span class="footer__link">
#         улица Искры, д. 17А, стр. 3,
#         <br/>
#         Москва, 129344, Россия
#        </span>
#        <span class="footer__link">
#         ИНН 7707450945
#         <br/>
#         ОГРН 1217700149590
#        </span>
#       </div>
#      </div>
#      <div class="footer__card">
#       <a aria-controls="collapseFive" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseFive" id="headingFive" role="button">
#        Связаться с нами
#       </a>
#       <div aria-labelledby="headingFive" class="footer__collapse collapse" id="collapseFive">
#        <a class="footer__link footer__link_hover" href="/contacts">
#         Контакты / Пресс-центр
#        </a>
#        <a class="footer__link footer__link_hover" href="/employers/258089/career#photoCompany">
#         Команда
#        </a>
#        <a class="footer__link footer__link_hover" href="/employers/258089/vakansii">
#         Вакансии
#        </a>
#        <a class="footer__link footer__link_hover" href="/employers/258089/blog">
#         Блог Dream Job
#        </a>
#       </div>
#      </div>
#      <div class="footer__card footer__card_left">
#       <a class="footer__title">
#        Служба поддержки
#       </a>
#       <div class="footer__collapse">
#        <span class="footer__link">
#         График работы:
#        </span>
#        <span class="footer__link">
#         Понедельник-пятница,
#         <br/>
#         с 9 до 18 по Москве.
#        </span>
#        <div>
#         <span class="footer__link footer__link_mail">
#          Для работодателей:
#         </span>
#         <a class="footer__mail" href="mailto:employers@dreamjob.ru">
#          employers@dreamjob.ru
#         </a>
#        </div>
#        <div>
#         <span class="footer__link footer__link_mail">
#          Для соискателей:
#         </span>
#         <a class="footer__mail" href="mailto:info@dreamjob.ru">
#          info@dreamjob.ru
#         </a>
#        </div>
#        <a class="footer__telegram" href="https://t.me/+-CLt0jp2KOUzOWIy" rel="nofollow noopener noreferrer" target="_blank" title="Dream Job в телеграмм">
#         Мы в телеграм
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="footer__info">
#      <div class="footer-top">
#       <p class="footer__text">
#        Dream Job — крупнейший в России сайт отзывов сотрудников,
#                     нам доверяют более 7 000 000 пользователей ежемесячно.
#       </p>
#       <p class="footer__text">
#        Миссия платформы — делать рынок труда в России прозрачнее и справедливее,
#                     помогать людям находить работу, а компаниям — становиться лучшими работодателями.
#       </p>
#      </div>
#      <div class="footer-bottom">
#       <p class="footer__text">
#        Dream Job использует файлы cookie с целью безопасности, а также
#                     оптимизации и персонализации сервисов и повышения удобства пользования сайтом.
#                     Cookie представляют собой небольшие файлы, содержащие информацию о предыдущих посещениях сайта.
#                     Если вы не хотите использовать файлы cookie, измените настройки браузера.
#       </p>
#       <p class="footer__text">
#        Свидетельство на товарный знак № 914157 от 09.01.2023 г
#        <br/>
#        © 2026. ООО "Дрим Джоб". Все права защищены.
#       </p>
#      </div>
#      <div class="footer-middle">
#       <!--dj rating-->
#       <a href="https://dreamjob.ru/employers/258089" rel="noopener" target="_blank">
#        <img alt="Dream Job отзывы сотрудников о работодателе на Dream Job" data-id="wg-258089-1-1" height="114" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg'%3E%3C/svg%3E" style="border:0" title="Рейтинг работодателя на Dream Job" width="170"/>
#       </a>
#       <script>
#        (function (s) {
#                     document.querySelectorAll("[data-id=wg-258089-1-1]").forEach(function (e) {
#                       e.src = s
#                     })
#                   }("https://dreamjob.ru/widget/light?employer_id=258089"))
#       </script>
#       <!--/dj rating-->
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script src="/assets/5e8b9362/jquery.min.js?v=1693204750">
#   </script>
#   <script src="/assets/84fcf258/yii.js?v=1767968650">
#   </script>
#   <script src="/assets/10afff40/jquery-ui.min.js?v=1473979674">
#   </script>
#   <script src="/assets/a0ab202/js/bootstrap.bundle.min.js?v=1773644475">
#   </script>
#   <script src="/assets/75dc149a/js/typeahead.bundle.min.js?v=1559106416">
#   </script>
#   <script src="/assets/75dc149a/js/typeahead-kv.min.js?v=1559106416">
#   </script>
#   <script src="/assets/38b60184/js/kv-widgets.min.js?v=1654067138">
#   </script>
#   <script src="/js/dj_data_save.js?v=1773644461">
#   </script>
#   <script src="/js/loader.min.js?v=1775227568">
#   </script>
#   <script src="/js/app.min.js?v=1773644461">
#   </script>
#   <script src="/assets/84fcf258/yii.activeForm.js?v=1767968650">
#   </script>
#   <script src="/assets/93882470/jquery.pjax.js?v=1768915604">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/centrifuge/5.2.0/centrifuge.min.js">
#   </script>
#   <script src="/assets/c3ae0fcc/js/centrifuge.js?v=1773644461">
#   </script>
#   <script src="/js/set-focus-on-search.js?v=1773644461">
#   </script>
#   <script src="/js/mobile-header-logo-switcher.js?v=1773644461">
#   </script>
#   <script>
#    jQuery(function ($) {
# jQuery('#pjax_form').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery(document).pjax("#data_pjax a", {"push":true,"replace":true,"timeout":0,"scrollTo":false,"container":"#data_pjax"});
# jQuery(document).off("submit", "#data_pjax form[data-pjax]").on("submit", "#data_pjax form[data-pjax]", function (event) {jQuery.pjax.submit(event, {"push":true,"replace":true,"timeout":0,"scrollTo":false,"container":"#data_pjax"});});
#
#
#     ((filter) => {
#         filter.submitForm = () => {
#             $.ajax({
#                 url: '/site/create-category-filter-form-action',
#                 data: new FormData(filter.getJQForm().get(0)),
#                 processData: false,
#                 contentType: false,
#                 type: 'POST',
#                 success: (data) => {
#                     if (filter.getCategoryInput()) {
#                         filter.getCategoryInput().disabled = true;
#                     }
#
#                     filter.getCityInput().disabled = true;
#
#                     filter.getJQForm().attr('action', data).submit();
#
#                     if (filter.getCategoryInput()) {
#                         filter.getCategoryInput().disabled = false;
#                     }
#
#                     filter.getCityInput().disabled = false;
#                 }
#             });
#         };
#
#         $(document).on('change', '#pjax_form input,select', () => {
#             $('._open-mobile-filters').css('overflow', 'scroll');
#             filter.submitForm();
#         });
#
#         $(document).on('pjax:end', '#data_pjax_more' ,function(){
#             let new_div = $(this).find('.industries-block__body');
#             let html = new_div.html();
#             new_div.remove();
#             $(html).appendTo('#main_employer_div');
#         });
#
#         $(document).on('pjax:end', function() {
#
#             var checkedFiltersAmount = $('input:checked', $('#pjax_form')).length;
#
#             if (checkedFiltersAmount === 0) {
#                 $('span', filter.getJQFilterIcon()).remove();
#             } else {
#                 filter.getJQFilterIcon().append('<span>' + checkedFiltersAmount + '</span>');
#             }
#
#             if (filter.getCategoryInput()) {
#                 filter.getCategoryInput().disabled = false;
#             }
#
#             filter.getCityInput().disabled = false;
#             filter.getSortInput().disabled = false;
#
#         });
#
#         $(document).on('click', '[type=reset]', () => {
#             if (filter.getCategoryInput()) {
#                 filter.getCategoryInput().checked = false;
#             }
#
#             filter.getCityInput().disabled = true;
#             filter.getSortInput().disabled = true;
#
#             filter.submitForm();
#
#             filter.getSortInput().disabled = false;
#         });
#
#     })({
#         getCategoryInput: () => document.querySelector('[name="category_id"]:checked'),
#         getCityInput: () => document.querySelector('[name="city"]'),
#         getSortInput: () => document.querySelector('[name="sort"]'),
#         getJQFilterIcon: () => $('[data-js="filter-icon"]'),
#         getJQForm: () => $('#pjax_form')
#     });
#
#     $(document).on('click', '#show_more_news', () => { window.scrollTo( {top: Math.round($('#pjax_form').offset().top), behavior: 'smooth'} ) })
#
#
# jQuery&&jQuery.pjax&&(jQuery.pjax.defaults.maxCacheLength=0);
# var w0_data_1 = new Bloodhound({"datumTokenizer":Bloodhound.tokenizers.obj.whitespace('value'),"queryTokenizer":Bloodhound.tokenizers.whitespace,"remote":{"url":"/ajax/search-employer?q=%QUERY","wildcard":"%QUERY"}});
# kvInitTA('w0', typeahead_3fe4d359, [{"display":"value","limit":10,"templates":{"suggestion":(o) => (`<p data-reach-goal="search_companies_top_list">${o.text}</p>`)},"name":"w0_data_1","source":w0_data_1.ttAdapter()}]);
# jQuery("#w0").on('typeahead:select', window.dj.actions.companySearchSuggestClick);
# jQuery("#w0").on('typeahead:render', window.dj.actions.companySearchTypeaheadRender);
# jQuery("#w0").on('typeahead:asyncrequest', window.dj.actions.ttLoadingHandler);
# jQuery("#w0").on('typeahead:asynccancel', window.dj.actions.ttLoadingHandler);
# jQuery("#w0").on('typeahead:asyncreceive', window.dj.actions.ttLoadingHandler);
# jQuery('#search_form_header').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery('#w1').yiiActiveForm([], []);
# });
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-26e44a76514b85cdf44","applicationID":"1111264889","transactionName":"YFxVZEUCCEVQBU1YXVkWdlNDCglYHhVQRVcYWlZEUgQJRFgDSg==","queueTime":1,"applicationTime":48,"atts":"TBtWEg0YG0s=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /company-month
# javascript:void(0)
# /salary
# /#search
# /vakansii
# /salary
# /page/employers
# /site/login
# /company-month
# /vakansii
# /salary
# /page/employers
# /site/login
# /categories
# /employers/26161
# /employers/25583
# /employers/26066
# /employers/25607
# /employers/26069
# /employers/25930
# /employers/26091
# /employers/6690
# /employers/25947
# /employers/25946
# /employers/25921
# /employers/37011
# /employers/56818
# /employers/26029
# /employers/25596
# /employers/46157
# /employers/26028
# /employers/26002
# /employers/2672030
# /employers/25924
# /employers/26011
# /employers/25879
# /employers/25704
# /employers/104847
# /employers/56859
# /employers/25920
# /employers/93692
# /employers/58994
# /employers/25931
# /employers/25908
# /employers/25918
# /employers/37657
# /employers/6424
# /employers/25903
# /employers/26156
# /employers/286960
# /categories?page=2&per-page=36
# #collapseOne
# /applicant2/reviews/index
# /anonym
# /salary
# /vakansii
# /categories
# /add
# #collapseTwo
# /employer
# /page/employers
# /guides/guide-copyright.pdf
# /guides/guide-visual.pdf
# /guides/guide-reviews-collect.pdf
# /guides/guide-widget.pdf
# /employers/258089/blog/apdejt-po-pilotu-korporativnyh-blogov-na-dream-job
# /site/register?role=employer_admin
# #collapseThree
# /employers/258089/career#blockCareer
# /principles
# /license-agreement
# /privacy
# /it-activity
# /article/software
# /release-notes
# #collapseFour
# #collapseFive
# /contacts
# /employers/258089/career#photoCompany
# /employers/258089/vakansii
# /employers/258089/blog
# None
# mailto:employers@dreamjob.ru
# mailto:info@dreamjob.ru
# https://t.me/+-CLt0jp2KOUzOWIy
# https://dreamjob.ru/employers/258089

# %%
import re

urls = set()

for link in soup.find_all('a'):
    if link.get('href'): # and link.get('href').startswith('https://'):
        link = re.findall(r'/employers/\d+', link.get('href'))

        if (len(link) > 0):
          urls.add(link[0])
urls = list(urls)
print(urls)
# Out:
# ['/employers/286960', '/employers/26066', '/employers/25908', '/employers/25924', '/employers/2672030', '/employers/6424', '/employers/6690', '/employers/26028', '/employers/25879', '/employers/26161', '/employers/37011', '/employers/56859', '/employers/25947', '/employers/46157', '/employers/25596', '/employers/93692', '/employers/25607', '/employers/37657', '/employers/26069', '/employers/25930', '/employers/25704', '/employers/25921', '/employers/25918', '/employers/25946', '/employers/26011', '/employers/26091', '/employers/56818', '/employers/25903', '/employers/26156', '/employers/25583', '/employers/258089', '/employers/25931', '/employers/26002', '/employers/25920', '/employers/26029', '/employers/58994', '/employers/104847']

# %%
url0 = urls[0]

page0 = requests.get('https://dreamjob.ru/'+url0)
soup0 = BeautifulSoup(page0.text, 'html')
soup0
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1134516852",accountID:"4709628",trustKey:"4709628",xpid:"UAEHWFBRABABVVBTBQcDXlwI",licenseKey:"NRJS-26e44a76514b85cdf44",applicationID:"1111264889",browserID:"1134516852"};;/*! For license information please see nr-loader-spa-1.312.1.min.js.LICENSE.txt */
# (()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,Zm:()=>c,bQ:()=>u,dV:()=>d,pV:()=>l});var n=r(6154),i=r(1863),s=r(944),o=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function c(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function d(){let e=c();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,o.i)(...Object.values(e.o))),e}function u(e,t){let r=c();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t,2===Object.keys(r.initializedAgents).length&&(0,s.R)(69)}function l(){return function(){let e=c();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=c();const t=e.init||{};e.init={...t}}(),d(),function(){let e=c();const t=e.loader_config||{};e.loader_config={...t}}(),c()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>a,df:()=>s,qY:()=>n,v4:()=>o});const n="events",i="jserrors",s="browser/blobs",o="rum",a="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.softNav]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.sessionReplay]:8,[c.logging]:9,[c.genericEvents]:10},u={[c.pageViewEvent]:o,[c.pageViewTiming]:n,[c.ajax]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:a,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>o,TZ:()=>a,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},o="log",a=n.K7.logging},1541:(e,t,r)=>{"use strict";r.d(t,{$5:()=>d,B5:()=>c,Ux:()=>o,YA:()=>a,fQ:()=>i});var n=r(5871);const i={MFE:"MFE",BA:"BA"};function s(e,t){if(!e||!t?.init.api.allow_registered_children)return[];const r=t.runtime.registeredEntities;return r?.filter(t=>t.metadata.timings?.asset?.endsWith(e)).map(e=>e.metadata.target)||[]}function o(e,t){if(!u(t))return{};const r=t.agentRef.runtime.appMetadata.agents[0].entityGuid;return e?e.attributes:{"entity.guid":r,appId:t.agentRef.info.applicationID}}function a(e,t){return c(e,t)?{"child.id":e.id,"child.type":e.type,...o(void 0,t)}:{}}function c(e,t){return!!e&&!!u(t)&&t.agentRef.init.api.duplicate_registered_data}function d(e){if(!e?.init.api.allow_registered_children)return[void 0];const t=[];try{var r=(0,n.AZ)((0,n.QL)());let i=r.length-1;for(;r[i];)t.push(...s(r[i--],e))}catch(e){}return t.length||t.push(void 0),t}function u(e){return 2===e?.harvestEndpointVersion}},1687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>a,Ze:()=>d,x3:()=>c});var n=r(3241),i=r(3606),s=r(860),o=r(2646);function a(e,t){if(!e)return;const r={staged:!1,priority:s.P3[t]||0};e.runtime.drainRegistry.get(t)||e.runtime.drainRegistry.set(t,r)}function c(e,t){if(!e)return;const r=e.runtime.drainRegistry;r&&(r.get(t)&&r.delete(t),l(e,t,!1),r.size&&u(e))}function d(e,t="feature",r=!1){if(e){if(!e.runtime.drainRegistry.get(t)||r)return l(e,t);e.runtime.drainRegistry.get(t).staged=!0,u(e)}}function u(e){if(!e)return;const t=Array.from(e.runtime.drainRegistry);t.every(([e,t])=>t.staged)&&(t.so ...
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Работа в Розничная сеть МТС ᐈ Отзывы сотрудников о работодателе Розничная сеть МТС, зарплаты</title>
# <meta content="Работа в Розничная сеть МТС ᐈ Отзывы сотрудников о работодателе Розничная сеть МТС, зарплаты | Dream Job" property="og:title"/>
# <meta content="https://dreamjob.ru/employers/286960" property="og:url"/>
# <meta content="2026-04-02T18:02:41+03:00" name="last-modified"/>
# <meta content="https://dreamjob.ru/i/dream-job.png" property="og:image"/>
# <meta content="Dream Job - крупнейший ресурс с отзывами сотрудников в России" property="og:image:alt"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1600" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Изучайте отзывы сотрудников о работе в компании Розничная сеть МТС. Будьте в курсе условий труда, зарплат, карьерных возможностей благодаря сервису Dream Job" name="description"/>
# <meta content="Изучайте отзывы сотрудников о работе в компании Розничная сеть МТС. Будьте в курсе условий труда, зарплат, карьерных возможностей благодаря сервису Dream Job" property="og:description"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.svg" rel="icon"/>
# <link href="https://dreamjob.ru/employers/286960" rel="canonical"/>
# <link href="/assets/10afff40/themes/smoothness/jquery-ui.min.css?v=1473979674" rel="stylesheet"/>
# <link href="/css/bs-4.6.1-dj.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead-kv.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/38b60184/css/kv-widgets.min.css?v=1654067138" rel="stylesheet"/>
# <link href="/css/roboto_font.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/general-styles.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/header-main.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/dj/pages/tab-reviews.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/bottomsheet.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/vendor/swiper/swiper-bundle.min.css?v=1773644461" rel="stylesheet"/>
# <link href="/assets/bfdec21e/css/select2.min.css?v=1580158882" rel="stylesheet"/>
# <link href="/assets/672b73b7/css/select2-addl.min.css?v=1646359914" rel="stylesheet"/>
# <link href="/assets/672b73b7/css/select2-krajee.min.css?v=1646359914" rel="stylesheet"/>
# <link href="/assets/bcb6bb43/css/main.min.css?v=1774862184" rel="stylesheet"/>
# <link href="/css/bottomsheet.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/assets/6b3b408e/css/filter_select.css?v=1773644461" rel="stylesheet"/>
# <link href="/assets/8a2a9e88/css/filter_checkbox.css?v=1773644461" rel="stylesheet"/>
# <link href="/assets/c3ae0fcc/css/centrifuge.css?v=1773644461" rel="stylesheet"/>
# <script src="/vendor/swiper/swiper-bundle.min.js?v=1773644461"></script>
# <script>var s2options_d6851687 = {"themeCss":".select2-container--krajee","sizeCss":"","doReset":true,"doToggle":false,"doOrder":false};
# window.select2_5a983b64 = {"placeholder":"Выберите должность","allowClear":true,"dropdownCssClass":"dropdown_salary_tab","containerCssClass":"open_vacacy_filter","theme":"krajee","width":"100%","language":"ru"};
#
# window.select2_8fbbd2a3 = {"data":[{"id":27,"text":"коллектив","count":1294,"allCount":1619},{"id":2,"text":"график работы","count":951,"allCount":1425},{"allCount":2390,"id":20,"text":"зарплата","count":854},{"id":18,"text":"расположение","count":724,"allCount":812},{"allCount":596,"id":1,"text":"карьерный рост","count":484},{"id":42,"text":"обучение","count":484,"allCount":575},{"id":25,"text":"руководство","count":355,"allCount":972},{"id":53,"text":"своевременная зарплата","count":265,"allCount":265},{"id":9,"text":"дмс","count":251,"allCount":296},{"allCount":533,"id":6,"text":"условия","count":174},{"allCount":461,"id":22,"text":"офис","count":163},{"id":50,"text":"отпуск","count":148,"allCount":148},{"id":17,"text":"соблюдение тк","count":144,"allCount":144},{"id":45,"text":"развитие","count":141,"allCount":145},{"id":7,"text":"корпоративная культура","count":123,"allCount":172},{"id":4,"text":"мотивация","count":123,"allCount":444},{"id":24,"text":"соц пакет","count":74,"allCount":77},{"id":8,"text":"отношение","count":70,"allCount":441},{"id":55,"text":"задачи","count":69,"allCount":69},{"id":48,"text":"опыт работы","count":56,"allCount":56},{"allCount":289,"id":34,"text":"отдых","count":42},{"id":37,"text":"удаленная работа","count":37,"allCount":44},{"id":54,"text":"больничный","count":28,"allCount":28},{"id":49,"text":"скидки для сотрудников","count":23,"allCount":23},{"allCount":39,"id":29,"text":"обратная связь","count":13},{"id":51,"text":"атмосфера","count":8,"allCount":8},{"allCount":9,"id":47,"text":"транспорт","count":6},{"id":52,"text":"подарки","count":3,"allCount":3},{"id":28,"text":"испытательный срок","count":2,"allCount":3},{"allCount":42,"id":46,"text":"питание","count":2},{"id":56,"text":"подработка","count":2,"allCount":2},{"id":11,"text":"наставничество","count":1,"allCount":3},{"id":31,"text":"оборудование","count":1,"allCount":3},{"id":16,"text":"спец одежда","count":1,"allCount":1}],"closeOnSelect":false,"dropdownParent":"#dj-select2-dropdown-wrap-1","dropdownCssClass":"build-in-select2__dropdown topics_praise","selectionCssClass":"build-in-select2__selection","templateResult":function(b){return b.id?`<a class="tags-new tags-new_option" data-id="${b.id}" role="button">${b.text} <span class="tags-new__count">(${b.count})</span></a>`:b.text},"escapeMarkup":function(m) { return m; },"highlight":false,"minLength":2,"theme":"krajee","width":"100%","placeholder":"Поиск по темам","language":"ru"};
#
# window.select2_ee4d27fd = {"data":[{"id":20,"text":"зарплата","count":1536,"allCount":2390},{"allCount":972,"id":25,"text":"руководство","count":617},{"allCount":1425,"id":2,"text":"график работы","count":474},{"allCount":441,"id":8,"text":"отношение","count":371},{"id":6,"text":"условия","count":359,"allCount":533},{"allCount":1619,"id":27,"text":"коллектив","count":325},{"allCount":444,"id":4,"text":"мотивация","count":321},{"id":26,"text":"взаимодействие","count":303,"allCount":303},{"id":22,"text":"офис","count":298,"allCount":461},{"id":34,"text":"отдых","count":247,"allCount":289},{"id":32,"text":"нагрузка","count":125,"allCount":125},{"id":1,"text":"карьерный рост","count":112,"allCount":596},{"allCount":575,"id":42,"text":"обучение","count":91},{"allCount":812,"id":18,"text":"расположение","count":88},{"allCount":172,"id":7,"text":"корпоративная культура","count":49},{"allCount":296,"id":9,"text":"дмс","count":45},{"id":46,"text":"питание","count":40,"allCount":42},{"id":29,"text":"обратная связь","count":26,"allCount":39},{"id":21,"text":"kpi","count":25,"allCount":25},{"id":3,"text":"обязанности","count":22,"allCount":22},{"id":36,"text":"мероприятия","count":12,"allCount":12},{"id":5,"text":"рабочий процесс","count":12,"allCount":12},{"id":19,"text":"программное обеспечение","count":11,"allCount":11},{"id":39,"text":"скидка","count":9,"allCount":9},{"allCount":44,"id":37,"text":"удаленная работа","count":7},{"id":10,"text":"опыт","count":5,"allCount":5},{"id":38,"text":"бизнес процесс","count":4,"allCount":4},{"id":15,"text":"дресс код","count":4,"allCount":4},{"id":43,"text":"колл центр","count":4,"allCount":4},{"allCount":145,"id":45,"text":"развитие","count":4},{"id":14,"text":"быт","count":3,"allCount":3},{"allCount":77,"id":24,"text":"соц пакет","count":3},{"id":47,"text":"транспорт","count":3,"allCount":9},{"id":13,"text":"баланс","count":2,"allCount":2},{"allCount":3,"id":11,"text":"наставничество","count":2},{"allCount":3,"id":31,"text":"оборудование","count":2},{"id":40,"text":"автоматизация процессов","count":1,"allCount":1},{"id":23,"text":"адаптация","count":1,"allCount":1},{"id":12,"text":"бюрократия","count":1,"allCount":1},{"allCount":3,"id":28,"text":"испытательный срок","count":1},{"id":44,"text":"парковка","count":1,"allCount":1},{"id":41,"text":"штраф","count":1,"allCount":1}],"closeOnSelect":false,"dropdownParent":"#dj-select2-dropdown-wrap-0","dropdownCssClass":"build-in-select2__dropdown topics_attention","selectionCssClass":"build-in-select2__selection","templateResult":function(b){return b.id?`<a class="tags-new tags-new_option" data-id="${b.id}" role="button">${b.text} <span class="tags-new__count">(${b.count})</span></a>`:b.text},"escapeMarkup":function(m) { return m; },"highlight":false,"minLength":2,"theme":"krajee","width":"100%","placeholder":"Поиск по темам","language":"ru"};
#
# window.typeahead_3fe4d359 = {"highlight":true,"minLength":2};
# </script>
# <script src="/js/fp_2_0_6.min.js"></script>
# <script>
#     Fingerprint2.get(function (cs) {
#         (function (w, d, s, l, i, c, fp, u, e, h) {
#             w[l] = w[l] || [];
#             w['fingerprint'] = {cs: cs, id: fp, uid: u, eid: e, hid: h};
#             w[l].push({fingerprint: fp});
#             if (u) w[l].push({user_id: u});
#             if (e) w[l].push({employer_id: e});
#             w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             try {
#                 c = JSON.parse(c);
#                 for (let p of Object.keys(c)) {
#                     w[l].push({event: 'FlagAssigned', 'flag_id': p, 'flag_is_on': c[p]});
#                 }
#             } catch (e) {
#             }
#                         /* Google Tag Manager */
#
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#             /* End Google Tag Manager */
#                     })(window, document, 'script', 'dataLayer', 'GTM-M3XGKC6', '',
#             Fingerprint2.x64hash128(cs.map(function (pair) {
#                 return pair.value
#             }).join(), 31), 0);
#     });
# </script> <meta content="_csrf" name="csrf-param"/>
# <meta content="yGoFiEhgp28r_SGm4W24lkLIzZheqBcCJmb57ddSf6_wX1TqHzGQWU6QdOSSC_fPG4Gv_TnaJjNkP6O5mWZSgg==" name="csrf-token"/>
# <script type="application/ld+json">{"@context":"https://schema.org","@type":"QAPage","mainEntity":{"@type":"Question","@id":"https://dreamjob.ru/employers/286960","name":"Специалист офиса продаж и обслуживания","text":"Расскажите о ваших впечатлениях от работы в Розничная сеть МТС, оставьте отзыв как действующий или бывший сотрудник об условиях труда, зарплате и карьерных возможностях.","answerCount":4012,"upvoteCount":4,"datePublished":"2021-09-01T18:12:12+03:00","author":{"@type":"Organization","name":"розничная сеть мтс","url":"https://job.mts.ru/vacancies/salony-prodazh"},"acceptedAnswer":{"@type":"Answer","@id":"https://dreamjob.ru/employers/286960?review_id=4496004","text":"📌 гибкий график, оплачиваемый отпуск и больничный, спец одежда, и это единственные плюсы","upvoteCount":4,"datePublished":"2026-03-06T01:49:42+03:00","author":{"@type":"Person","name":"Специалист офиса продаж и обслуживания","url":"https://dreamjob.ru/employers/286960?review_id=4496004"},"url":"https://dreamjob.ru/employers/286960?review_id=4496004"}},"suggestedAnswer":[{"@type":"Answer","@id":"https://dreamjob.ru/employers/286960?review_id=3752975","text":"📌 Вообще ничего хорошего, не советую туда ходить только терять время в пустую. Очень пожалела, что работала в МТС","upvoteCount":4,"datePublished":"2025-06-07T15:24:55+03:00","author":{"@type":"Person","name":"Отзыв сотрудника","url":"https://dreamjob.ru/employers/286960?review_id=3752975"},"url":"https://dreamjob.ru/employers/286960?review_id=3752975"},{"@type":"Answer","@id":"https://dreamjob.ru/employers/286960?review_id=4260622","text":"📌 Начальство способно идти на компромиссы, график выстраивается по договоренности","upvoteCount":3,"datePublished":"2025-12-03T12:15:26+03:00","author":{"@type":"Person","name":"Менеджер по продажам","url":"https://dreamjob.ru/employers/286960?review_id=4260622"},"url":"https://dreamjob.ru/employers/286960?review_id=4260622"},{"@type":"Answer","@id":"https://dreamjob.ru/employers/286960?review_id=2213925","text":"📌 1) График можно подстроить под себя, есть возможность брать смены на 4/6/8/12 часов. Можно было планировать свои дела заранее и совмещать их с удобным графиком.  2) Плюшки от довольных клиентов. Иногда вам будут дарить различные презенты – шоколадки, денежку, даже цветы!  3) Выплата заработной платы день в день. Здесь всё честно, 10 и 25 в обед приходили денежные средства. В большинстве случаев её рассчитывали правильно и всё сходилось. Бухгалтера на работе это вообще одна из сильных сторон.","upvoteCount":3,"datePublished":"2023-12-21T03:22:00+03:00","author":{"@type":"Person","name":"Руководитель офиса продаж","url":"https://dreamjob.ru/employers/286960?review_id=2213925"},"url":"https://dreamjob.ru/employers/286960?review_id=2213925"},{"@type":"Answer","@id":"https://dreamjob.ru/employers/286960?review_id=2746705","text":"📌 к сожалению, ничего не понравилось","upvoteCount":3,"datePublished":"2024-07-17T20:36:51+03:00","author":{"@type":"Person","name":"Специалист по работе с клиентами","url":"https://dreamjob.ru/employers/286960?review_id=2746705"},"url":"https://dreamjob.ru/employers/286960?review_id=2746705"}]}</script> </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3XGKC6" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script>var centrifugoOptions = {"wsConnectionEndpoint":"wss:\/\/centrifugo.dreamjob.ru:443\/connection\/websocket","connectionToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI1NmQ5Njg5MjBlY2I3ZjJhMjU4YzkwMTRlMjg4ZWQ5NCJ9.1VD22b_69h4w3qUuATYbZ-Nilszl8lYXBWEjeHoiwu0","subscriptionTokens":{"main-channel":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjaGFubmVsIjoibWFpbi1jaGFubmVsIiwic3ViIjoiNTZkOTY4OTIwZWNiN2YyYTI1OGM5MDE0ZTI4OGVkOTQifQ.SX5FmcdBqhyQenWLGz3CTrf3JPSTg7hCCwdve86SpnY"},"userRoles":"guest","userId":"56d968920ecb7f2a258c9014e288ed94"};</script>
# <header class="header">
# <div class="container">
# <nav class="navbar navbar-expand-lg">
# <a class="dreamjob-logo__wrapper order-0" href="/" title="Главная Dream Job">
# <img alt="Dream Job логотип" class="dreamjob-logo__icon" src="/i/logo/logo.svg"/>
# <img alt="Dream Job название компании" class="dreamjob-logo__name" src="/i/logo/brand.svg"/>
# </a>
# <a class="monthly-award-tag" data-event-click='{"event_id":4,"scenario":"employer_month","event_type":1}' data-event-show='{"event_id":3,"scenario":"employer_month","event_type":1}' href="/company-month">
# <img alt="" class="monthly-award-tag__logo" src="/images/icons/month-company/ears-of-wheat_sm.svg"/>
# <span class="monthly-award-tag__text">Компания месяца</span>
# </a>
# <div class="input-group mob_input md-form form-sm form-2 d-lg-none order-3" id="headerMobSearch">
# <button class="header__btn-close reset-button" data-action="toggleClass" data-class="open_inp" data-target="#headerMobSearch" type="button">
# <svg class="rc__tLLGP" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M20 0v20V0ZM0 20V0v20Zm8.116-3.823-5.469-5.47a.999.999 0 0 1 0-1.414l5.469-5.47a.5.5 0 0 1 .707 0l.354.354a.5.5 0 0 1 0 .707L4.811 9.25H17.5a.5.5 0 0 1 .5.5v.5a.5.5 0 0 1-.5.5H4.811l4.366 4.366a.5.5 0 0 1 0 .707l-.354.354a.5.5 0 0 1-.707 0Z" fill="#3460A4" fill-rule="evenodd"></path>
# </svg>
# </button>
# <form action="/site/search" class="tt__wrap" id="search_form_header" method="get"> <div class="tt-scrollable-menu"><input aria-label="Search" autocomplete="off" class="form-control input-field" data-input-action="ttInputHandlerTopSearch" data-krajee-typeahead="typeahead_3fe4d359" id="w2" name="query" placeholder="Введите название компании" type="text"/></div>
# <button class="header__button-find reset-button" data-reach-goal="search_companies_top_button" type="submit"></button>
# <div class="tt__clear" data-action="ttClear"></div>
# </form>
# </div>
# <a class="header-button header-button--search d-lg-none order-2" data-action="headerSearchOpen" href="javascript:void(0)" role="button" title="Поиск компаний"></a>
# <!--            <a href="-->
# <!--" class="order-2 header-button header-button--vacancies d-lg-none"-->
# <!--               title="Вакансии" data-action="gaPush"-->
# <!--               data-layer-push='{"event":"vacancies_name_click"}' data-reach-goal="vacancies_top_button_click"-->
# <!--               data-event-click='-->
# <!--'-->
# <!--            >-->
# <a class="order-2 header-button header-button--wallet d-lg-none" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary" title="Зарплаты">
# </a>
# <!-- --> <div aria-controls="navContent" aria-expanded="false" class="bt icon-bg-burger reset-button d-lg-none order-2 collapsed" data-target="#navContent" data-toggle="collapse" role="button"></div>
# <div class="collapse navbar-collapse order-3" id="navContent">
# <!--               <div style="flex: 1 0;" class="input-group md-form form-sm form-2 pl-0 header__search-form d-none d-lg-block">-->
# <!--                   <form method="get" class="tt__wrap" action="-->
# <!--">-->
# <!-- --> <!--                        <button class="header__button-find reset-button" type="submit" data-reach-goal="search_companies_top_button"></button>-->
# <!--                        <div class="tt__clear" data-action="ttClear"></div>-->
# <!--                    </form>-->
# <!--               </div>-->
# <div class="header__buttons">
# <!--                    <a class="monthly-award-tag">-->
# <!--                        <img class="monthly-award-tag__logo logo" src="/images/icons/recommendations/ears-of-wheat.svg" alt="">-->
# <!--                        <span class="monthly-award-tag__text text">Компания месяца</span>-->
# <!--                    </a>-->
# <a class="header-button header-button--search d-none d-lg-block" href="/#search">
#                                 Поиск
#                             </a>
# <a class="header-button header-button--vacancies d-none d-lg-block" data-action="gaPush" data-event-click='{"event_id":24,"scenario":"jb"}' href="/vakansii">
#                                 Вакансии
#                             </a>
# <a class="header-button header-button--wallet d-none d-lg-block" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary">
#                                 Зарплаты
#                             </a>
# <a class="header-button header-button--for-employer d-none d-lg-block" href="/page/employers">Работодателям</a>
# <a class="header-button header-button--user d-none d-lg-block" href="/site/login">Войти</a>
# <div class="mob_menu d-lg-none js-modile-menu">
# <div class="inner-menu">
# <div class="inner_block-menu">
# <ul>
# <li class="month-company__burger-menu-item">
# <a class="bt body2r bt--primary-link icon-bg-ears-of-wheat_rounding" data-event-click='{"event_id":6,"scenario":"employer_month"}' data-event-show='{"event_id":5,"scenario":"employer_month"}' href="/company-month">Компания месяца</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-vacancies" href="/vakansii">Вакансии</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-wallet" href="/salary">Зарплаты</a></li>
# <li><a class="bt body2r bt--primary-link icon-bg-bag" href="/page/employers">Работодателям</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-profile" href="/site/login">Вход в личный кабинет</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div class="company-header" data-employer-id="286960" data-js="employerHeader">
# <div class="banner mobileBannerExist">
# <div class="container">
# <img alt="баннер Розничная сеть МТС" class="old-banner show-mobile-old-banner img-default" src="https://cdn.dreamjob.ru/employer/286960/675c8cbcb0071MTzc-X.png"/>
# </div>
# <div class="show-desktop-old-banner">
# <div class="container">
# <div class="default-banner">
# <a class="banner__button bt bt--32 bt--primary-outline" data-action="gaPush" data-layer-push='{"event":"Manage_Employer_Profile_Click"}' href="/page/employers">
#         Управлять профилем работодателя
#     </a>
# </div>
# </div>
# </div>
# </div>
# <div class="company-header__info">
# <div class="company-header__info_top">
# <div class="container-md">
# <div class="company">
# <div class="company__block">
# <div class="company__logo">
# <a class="company__link-img" href="/employers/286960" title="Розничная сеть МТС">
# <img alt="Розничная сеть МТС отзывы сотрудников" class="company__img-logo" src="https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png"/>
# </a>
# </div>
# <div class="company__name_wrap">
# <div class="company__name line-clamp-2" data-js="companyName">
#                                     Розничная сеть МТС                                </div>
# <div class="company__open d-none d-md-flex" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="company__indicators">
# <div class="company__indicator company__rating d-md-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">3,3</div>
# <div class="dj-rating86 dj-rating86_no-value dj-rating86--30"></div>
# </div>
# <div class="company__indicator-text">Хорошо</div>
# </div>
# <div class="company__indicator company__recommend d-none d-lg-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">48%</div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:47.63%;"></div>
# </div>
# </div>
# <div class="company__indicator-text">Рекомендуют</div>
# </div>
# <div class="company__open ml-0 d-md-none" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="company__buttons">
# <a class="bt bt--success d-md-none company__buttons-add" data-action="gaPush" data-event-click='{"event_id":7,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960" id="write_review_mobile">
#                                     Оставить отзыв
#                                 </a>
# <a class="bt bt--soft-outline d-md-none company__buttons-compare" data-event-click='{"event_id":8,"scenario":"employer_public","employer_id":286960}' data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#                                     Сравнить
#                                 </a>
# </div>
# </div>
# </div>
# <div class="company fixed-company-hidden">
# <div class="company__block" id="topPage">
# <div class="company__logo logo--88-64">
# <span class="logo" style="background-image: url('https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png')"></span>
# </div>
# <div class="company__name_wrap">
# <div class="company__name line-clamp-2" data-js="companyName">
#                                     Розничная сеть МТС                                </div>
# <div class="company__open d-none d-md-flex" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="company__indicators">
# <div class="company__indicator company__rating d-md-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">3,3</div>
# <div class="dj-rating86 dj-rating86_no-value dj-rating86--30"></div>
# </div>
# <div class="company__indicator-text">Хорошо</div>
# </div>
# <div class="company__indicator company__recommend d-none d-lg-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">48%</div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:47.63%;"></div>
# </div>
# </div>
# <div class="company__indicator-text">Рекомендуют</div>
# </div>
# <div class="company__open ml-0 d-md-none" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="company__buttons">
# <a class="bt bt--success d-md-none company__buttons-add" data-action="gaPush" data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960" id="write_review_header">
#                                     Оставить отзыв
#                                 </a>
# <a class="bt bt--soft-outline d-md-none company__buttons-compare" data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#                                     Сравнить
#                                 </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="awards awards__modal d-none">
# <div class="awards-track awards-track__dashboard">
# <div class="awards-track__header">
# <div class="awards-track__header-wrapper">
# <span class="awards-track__heading">Награды компании</span>
# <span class="awards-track__quantity">0 наград из 4</span>
# </div>
# <span class="awards__modal-close-button" data-event-click='{"event_id":17,"scenario":"award"}'></span>
# </div>
# <div class="awards-carts awards-carts__wrapper flex-wrap">
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Лидер обратной связи">
# <span class="awards-carts__heading">Лидер обратной связи</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:8%"></div>
# </div>
# <span class="awards-carts__in-progress-label">8% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_messages"></span>
# <span class="awards-carts__information">Есть у 1% компаний на Dream Job</span>
# <p class="awards-carts__text">Компания поддерживает открытый диалог с сотрудниками, оперативно отвечая на каждый отзыв</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Забота о сотрудниках">
# <span class="awards-carts__heading">Забота о сотрудниках</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:57%"></div>
# </div>
# <span class="awards-carts__in-progress-label">57% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_hurt"></span>
# <span class="awards-carts__information">Есть у 1.1% компаний на Dream Job</span>
# <p class="awards-carts__text">Работодатель поддерживает достойные условия труда и отдыха для сотрудников</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Карьерный рост">
# <span class="awards-carts__heading">Карьерный рост</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:82%"></div>
# </div>
# <span class="awards-carts__in-progress-label">82% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_uptrand"></span>
# <span class="awards-carts__information">Есть у 1.8% компаний на Dream Job</span>
# <p class="awards-carts__text">В компании есть возможности для карьерного и профессионального роста сотрудников</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Корпоративная культура">
# <span class="awards-carts__heading">Корпоративная культура</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:84%"></div>
# </div>
# <span class="awards-carts__in-progress-label">84% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_handshake"></span>
# <span class="awards-carts__information">Есть у 2.8% компаний на Dream Job</span>
# <p class="awards-carts__text">Сотрудники отмечают профессионализм руководства и хорошую атмосферу в коллективе</p>
# </div>
# </div>
# </div>
# </div>
# <div class="sticky-block js-sticky-block">
# <div class="container-md" data-js="employerTabs">
# <div class="tabs" data-behavior="tabs">
# <a class="tabs__item tabs__item_career" data-ajax-tab="site_employer_career" data-event-click='{"event_id":1,"scenario":"employer_public","employer_id":286960}' href="/employers/286960/career" id="tab_career">
# <span class="tabs__text">О компании</span>
# </a>
# <a class="tabs__item _active" data-action="gaPush" data-ajax-tab="site_employer_reviews" data-event-click='{"event_id":2,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"reviews"}' data-reach-goal="tab_reviews" href="/employers/286960" id="tab_reviews">
# <span class="tabs__text">Отзывы </span>
# <span class="tabs__count">4 012</span>
# </a>
# <a class="tabs__item tabs__item_vacancies" data-event-click='[{"event_id":1,"scenario":"jb","employer_id":286960},{"event_id":3,"scenario":"employer_public","employer_id":286960}]' href="/employers/286960/vakansii" id="tab_vacancies-new">
# <span class="tabs__text">Вакансии </span>
# <span class="tabs__count">626</span>
# </a>
# <a class="tabs__item" data-action="gaPush" data-ajax-tab="site_employer_salary" data-event-click='{"event_id":4,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"salary"}' data-reach-goal="tab_salary" href="/employers/286960/zarplata" id="tab_salary">
# <span class="tabs__text">Зарплаты </span>
# <span class="tabs__count">1 596</span>
# </a>
# <a class="tabs__item" data-action="gaPush" data-ajax-tab="site_employer_interviews" data-event-click='{"event_id":5,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"interviews"}' data-reach-goal="dj_interviews" href="/employers/286960/interviews" id="tab_interviews">
# <span class="tabs__text">Собеседования </span>
# <span class="tabs__count">113</span>
# </a>
# <a class="bt-master bt-master_blue d-none d-md-inline-flex" data-action="gaPush" data-event-click='{"event_id":7,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960">
#             Оставить отзыв
#         </a>
# <a class="bt-40 d-none d-xl-inline-flex" data-event-click='{"event_id":8,"scenario":"employer_public","employer_id":286960}' data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#             Сравнить
#         </a>
# </div>
# </div>
# </div>
# <div data-pjax-container="" data-pjax-push-state="" data-pjax-replace-state="" data-pjax-scrollto="" data-pjax-timeout="0" id="data_pjax">
# <main class="e-tab reviews reviews--new-filter" data-event-page-closed='{"event_id":17,"scenario":"employer_public","event_type":2,"employer_id":286960}' data-event-page-loaded='{"event_id":16,"scenario":"employer_public","event_type":2,"employer_id":286960}' id="site_employer_reviews">
# <div class="container">
# <div class="js-scroll-reviews"></div>
# <h1 class="reviews__title" data-js="tab-title">Отзывы сотрудников о компании Розничная сеть МТС</h1>
# <div class="row">
# <div class="col-lg-8 reviews__content order-1 order-lg-2">
# <div class="d-block d-sm-none">
# <div class="dashboard block-24-16" data-js-id="dashboard" id="dashboard">
# <div class="dashboard__item dashboard__item--divider--right">
# <div class="dashboard__item-title">
#             Оценка компании
#         </div>
# <div class="dashboard__grade-wrapper">
# <div class="dashboard__grade">
# <div class="dashboard__grade-total">3,3</div>
# <div>
# <div class="dashboard__grade-humanly">Хорошо</div>
# <div class="dashboard__grade-reviews">4 012 отзывов</div>
# </div>
# </div>
# <div class="dashboard__grade-rates">
# <div class="dashboard__grade-rates-col">
# <label class="checkbox">
# <span class="dashboard__grade-rates-val">4-5</span>
# <input class="dashboard__rates-checkbox" data-attribute="ratings" type="checkbox" value="4"/>
# <i></i>
# </label>
# <label class="checkbox">
# <span class="dashboard__grade-rates-val">3-4</span>
# <input class="dashboard__rates-checkbox" data-attribute="ratings" type="checkbox" value="3"/>
# <i></i>
# </label>
# <label class="checkbox">
# <span class="dashboard__grade-rates-val">2-3</span>
# <input class="dashboard__rates-checkbox" data-attribute="ratings" type="checkbox" value="2"/>
# <i></i>
# </label>
# <label class="checkbox">
# <span class="dashboard__grade-rates-val">1-2</span>
# <input class="dashboard__rates-checkbox" data-attribute="ratings" type="checkbox" value="1"/>
# <i></i>
# </label>
# </div>
# <div class="dashboard__grade-rates-col dashboard__grade-rates-col--stretch">
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:33%;"></div>
# </div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:28%;"></div>
# </div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:27%;"></div>
# </div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:12%;"></div>
# </div>
# </div>
# <div class="dashboard__grade-rates-col">
# <span class="dashboard__grade-rates-amount">1 338</span>
# <span class="dashboard__grade-rates-amount">1 143</span>
# <span class="dashboard__grade-rates-amount">1 069</span>
# <span class="dashboard__grade-rates-amount">462</span>
# </div>
# </div>
# </div>
# </div>
# <div class="dashboard__item dashboard__chart dashboard__item--divider--top">
# <svg fill="none" height="40" width="40" xmlns="http://www.w3.org/2000/svg">
# <circle cx="20" cy="20" r="17" stroke="#EEEEEE" stroke-width="6"></circle>
# <circle cx="20" cy="20" r="17" stroke="#FFC107" stroke-dasharray="50.875579750764,106.81415022205" stroke-width="6" transform="rotate(-90,20,20)"></circle>
# </svg>
# <div class="dashboard__recommends">
# <div class="h5_m">48%</div>
# <div class="label2_r">Рекомендуют работодателя</div>
# </div>
# </div>
# <div class="dashboard__item dashboard__item--divider--top">
# <div class="dashboard__item-title">
#             Оценки по категориям
#         </div>
# <div class="dashboard__ratings">
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">3,4</div>
# <div class="dashboard__rating-label">Условия труда</div>
# </div>
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">4,2</div>
# <div class="dashboard__rating-label">Коллектив</div>
# </div>
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">3,2</div>
# <div class="dashboard__rating-label">Руководство</div>
# </div>
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">2,8</div>
# <div class="dashboard__rating-label">Уровень дохода</div>
# </div>
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">2,8</div>
# <div class="dashboard__rating-label">Условия для отдыха</div>
# </div>
# <div class="dashboard__rating">
# <div class="dashboard__rating-val">3,5</div>
# <div class="dashboard__rating-label">Возможности роста</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wage__inner">
# <div class="wage__list-top salary-select">
# <div class="kv-plugin-loading loading-vacancies_select"> </div><input name="nrs[vacancies]" type="hidden" value=""/><select class="form-control" data-event-select2-select='{"employer_id":286960,"event_type":7,"field_name":"nrs[vacancies]","event_id":7,"scenario":"filter"}' data-krajee-select2="select2_5a983b64" data-s2-options="s2options_d6851687" data-set-global='{"event_type":7,"employer_id":286960,"scenario":"filter","event_id":5}' id="vacancies_select" multiple="" name="nrs[vacancies][]" size="4" style="width: 1px; height: 1px; visibility: hidden;">
# <option value="3061">Специалист по продажам</option>
# <option value="2010">Специалист по работе с клиентами</option>
# <option value="2804">Начальник офиса продаж</option>
# <option value="369">Продавец-консультант</option>
# <option value="2786">Начальник отдела продаж</option>
# <option value="327">Директор магазина</option>
# <option value="2802">Начальник офиса</option>
# <option value="2">Менеджер по продажам</option>
# <option value="648">Менеджер по работе с клиентами</option>
# <option value="2806">Начальник сети офисов</option>
# <option value="9">Директор</option>
# <option value="3000">Специалист отдела продаж</option>
# <option value="1991">Специалист офиса продаж и обслуживания</option>
# <option value="2569">Менеджер офиса продаж</option>
# <option value="135">Продавец</option>
# <option value="2580">Менеджер по подбору персонала</option>
# <option value="3418">Старший смены</option>
# <option value="218">Руководитель отдела продаж</option>
# <option value="3060">Руководитель офиса продаж</option>
# <option value="35">Кладовщик</option>
# <option value="2049">Оператор call-центра</option>
# <option value="25">Специалист технической поддержки</option>
# <option value="3069">Специалист офиса</option>
# <option value="3013">Старший специалист отдела продаж</option>
# <option value="630">Консультант</option>
# <option value="356">Продавец-кассир</option>
# <option value="2650">Территориальный менеджер</option>
# <option value="266">Агент по продажам</option>
# <option value="212">Старший менеджер по продажам</option>
# <option value="413">Тренер</option>
# <option value="442">Ведущий юрисконсульт</option>
# <option value="1400">Начальник дополнительного офиса</option>
# <option value="7">Начальник отдела</option>
# <option value="1168">Специалист по подбору персонала</option>
# <option value="2012">Старший специалист по работе с клиентами</option>
# <option value="43">Аналитик</option>
# <option value="297">Бизнес-тренер</option>
# <option value="12">Бухгалтер</option>
# <option value="449">Менеджер активных продаж</option>
# <option value="2495">Менеджер отдела продаж</option>
# <option value="291">Менеджер по персоналу</option>
# <option value="2626">Менеджер по продажам услуг</option>
# <option value="2602">Помощник менеджера по продажам</option>
# <option value="3391">Специалист связи</option>
# <option value="1868">Старший продавец</option>
# <option value="1328">Директор филиала</option>
# <option value="345">Заместитель директора</option>
# <option value="2197">Ревизор контрольно-ревизионного отдела</option>
# <option value="1182">Руководитель группы</option>
# <option value="120">Руководитель отдела клиентского обслуживания</option>
# <option value="2008">Специалист по продажам и работе с клиентами</option>
# <option value="3473">Специалист по эксплуатации</option>
# <option value="210">Торговый представитель</option>
# <option value="610">Ассистент руководителя</option>
# <option value="1311">Директор офиса</option>
# <option value="1901">Категорийный менеджер</option>
# <option value="283">Менеджер по маркетингу</option>
# <option value="2124">Менеджер проектов</option>
# <option value="2244">Менеджер салона</option>
# <option value="2788">Начальник отдела розничных продаж</option>
# <option value="314">Офис-менеджер</option>
# <option value="414">Промоутер</option>
# <option value="2141">Промоутер-консультант</option>
# <option value="1315">Региональный директор по продажам</option>
# <option value="2582">Рекрутер</option>
# <option value="3182">Руководитель направления</option>
# <option value="10">Руководитель проектов</option>
# <option value="70">Специалист 1С</option>
# <option value="1389">Специалист по документообороту</option>
# <option value="342">Специалист по кадрам</option>
# <option value="370">Старший продавец-консультант</option>
# <option value="854">Старший юрисконсульт</option>
# <option value="2365">Управляющий магазином</option>
# <option value="2676">Управляющий менеджер</option>
# <option value="229">Администратор</option>
# <option value="346">Администратор магазина</option>
# <option value="387">Администратор офиса</option>
# <option value="448">Ведущий менеджер по продажам</option>
# <option value="1219">Делопроизводитель</option>
# <option value="1324">Директор салона</option>
# <option value="1284">Заместитель директора магазина</option>
# <option value="1287">Заместитель директора по продажам</option>
# <option value="2497">Заместитель начальника</option>
# <option value="1517">Заместитель начальника отдела продаж</option>
# <option value="1506">Заместитель руководителя</option>
# <option value="1131">Кладовщик-комплектовщик</option>
# <option value="1933">Кладовщик-оператор</option>
# <option value="2524">Менеджер по обучению</option>
# <option value="2817">Начальник сектора</option>
# <option value="20">Оператор</option>
# <option value="2496">Региональный менеджер</option>
# ...
#             }
#
#         } else {
#             $('#nrs-ratings').val(JSON.stringify([]));
#
#             if (first_selected.val() === $(this).attr('data-attribute')) {
#                 first_selected.val('');
#             }
#         }
#
#         let form = $('#form_nrs');
#         let url = form.attr('action');
#
#         let isFormNotEmpty = false;
#
#         for (let input of form.serializeArray()) {
#             if (input.value !== '[]' && input.value !== '') {
#                 isFormNotEmpty = true;
#                 break;
#             }
#         }
#
#         if (isFormNotEmpty && form.serialize()) {
#             url += '?' + form.serialize();
#         }
#
#         $.pjax({url : url, container : '#data_pjax', timeout: 0, scrollTo: false});
#     })
#
# jQuery&&jQuery.pjax&&(jQuery.pjax.defaults.maxCacheLength=0);
# if (jQuery('#vacancies_select').data('select2')) { jQuery('#vacancies_select').select2('destroy'); }
# jQuery.when(jQuery('#vacancies_select').select2(select2_5a983b64)).done(initS2Loading('vacancies_select','s2options_d6851687'));
# jQuery('#vacancies_select').on('select2:select', dj.stats.yandexGoal("designation_from_list"));
#
#
# $(document).ready(function () {
#     dj.actions.onReviewInViewPort = function() { //ивент для отправки просмотра отзывов пользователем в выдаче (на скролле)
#         const targetReviewIds = [3,6,9]; //целевые номера отзывов для отслеживания
#         const reviewQueueId = [...document.querySelectorAll('.review')].indexOf(this.closest('.review')) + 1 //порядковый номер отзыва в выдаче
#         if(targetReviewIds.includes(reviewQueueId)) {
#             window.dj.stats.yandexGoal('view_'+reviewQueueId+'_reviews');//отправка в яндекс метрику через reachGoal
#         }
#     }
#
#     $(document).on('pjax:end', function (e) {
#         if(e.target.id === 'data_pjax') {
#             const interval = setInterval(() => {
#                 if(document.querySelector('[data-stat]')?.getBoundingClientRect().top > window.scrollY) {
#                     clearInterval(interval);
#                     updateObserver();
#                 }
#             },250)
#         }
#     })
#
#     function updateObserver() {
#         dj.core.intersectionObserverAdd($('[data-action-view-port]'))
#     }
# })
#
# if (jQuery('#topics-select-1').data('select2')) { jQuery('#topics-select-1').select2('destroy'); }
# jQuery.when(jQuery('#topics-select-1').select2(select2_8fbbd2a3)).done(initS2Loading('topics-select-1','s2options_d6851687'));
# jQuery('#topics-select-1').on('select2:closing', function(e){ e.preventDefault(); $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-1').on('select2:open', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-1').on('select2:select', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-1').on('select2:unselect', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
#
# if (jQuery('#topics-select-0').data('select2')) { jQuery('#topics-select-0').select2('destroy'); }
# jQuery.when(jQuery('#topics-select-0').select2(select2_ee4d27fd)).done(initS2Loading('topics-select-0','s2options_d6851687'));
# jQuery('#topics-select-0').on('select2:closing', function(e){ e.preventDefault(); $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-0').on('select2:open', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-0').on('select2:select', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
# jQuery('#topics-select-0').on('select2:unselect', function(e){ $(".select2-search__field", this.parentNode).attr("placeholder","Поиск по темам"); });
#
#
#     const companyHeader = $('.company-header__info');
#
#     dj.actions.selectTopicsUI = function () {
#         const sentiment = +$(this).data('sentiment');
#         const select = $('#dj-select2-' + sentiment);
#         const title = sentiment ? 'Сотрудники хвалят' : 'Обращают внимание';
#
#         if (window.innerWidth < 768) {
#             //на мобильных bottomsheet
#             const sheet = $('#sheet');
#             $('.build-in-select2', sheet).hide();
#             $('[data-js="title"]', sheet).text(title);
#             $('[data-js="body"]', sheet).append(select.show());
#             sheet.trigger('dj-b-sheet:open');
#         } else {
#             //на десктопе модалка
#             const dlg = $('#topics-modal');
#             $('.build-in-select2', dlg).hide();
#             $('[data-js="title"]', dlg).text(title);
#             $('[data-js="body"]', dlg).append(select.show());
#             dlg.modal();
#         }
#
#         $('#topics-select-' + sentiment).select2('open');
#     }
#
#     dj.actions.topicsSelectClear = function() {
#         $(this).closest('[data-js="topics-block"]');
#
#         const first_selected = $('#form_nrs').find('.js_selected_values_first_selected');
#
#         $('#nrs-topics_0').val(JSON.stringify([]));
#         $('#nrs-topics_1').val(JSON.stringify([]));
#
#         if (first_selected.val() === 'topics') {
#             first_selected.val('');
#         }
#
#         let form = $('#form_nrs');
#         let url = form.attr('action');
#
#         let isFormNotEmpty = false;
#
#         for (let input of form.serializeArray()) {
#             if (input.value !== '[]' && input.value !== '' && input.id !== "nrs-first_selected") {
#                 isFormNotEmpty = true;
#                 break;
#             }
#         }
#
#         if (isFormNotEmpty && form.serialize()) {
#             url += '?' + form.serialize();
#         }
#
#         if (window.innerWidth < 768) {
#             //на мобильных bottomsheet
#             const sheet = $('#sheet');
#             sheet.trigger('dj-b-sheet:close')
#         } else {
#             //на десктопе модалка
#             const dlg = $('#topics-modal');
#             dlg.modal('hide')
#         }
#
#         $.pjax({url : url, container : '#data_pjax', timeout: 0, scrollTo: false});
#     }
#
#     dj.actions.topicsSelectApply = function() {
#
#         const block = $(this).closest('[data-js="topics-block"]');
#
#         const first_selected = $('#form_nrs').find('.js_selected_values_first_selected');
#         var isNotEmptyTopics = false;
#
#         $('select', block).each(function() {
#             const select = $(this);
#             const sentiment = select.closest('[data-sentiment]').data('sentiment')
#             const val = select.val();
#
#             $('#nrs-topics_' + sentiment).val(JSON.stringify(val));
#             if (val.length !== 0) {
#                 isNotEmptyTopics = true;
#             }
#         });
#
#         if (first_selected.val() === '' && isNotEmptyTopics) {
#             first_selected.val('topics');
#         }
#
#
#         if (first_selected.val() === 'topics' && !isNotEmptyTopics) {
#             first_selected.val('');
#         }
#
#         let form = $('#form_nrs');
#         let url = form.attr('action');
#
#         let isFormNotEmpty = false;
#
#         for (let input of form.serializeArray()) {
#             if (input.value !== '[]' && input.value !== '' && input.id !== "nrs-first_selected") {
#                 isFormNotEmpty = true;
#                 break;
#             }
#         }
#
#         if (isFormNotEmpty && form.serialize()) {
#             url += '?' + form.serialize();
#         }
#
#         if (window.innerWidth < 768) {
#             //на мобильных bottomsheet
#             const sheet = $('#sheet');
#             sheet.trigger('dj-b-sheet:close')
#         } else {
#             //на десктопе модалка
#             const dlg = $('#topics-modal');
#             dlg.modal('hide')
#         }
#
#         $.pjax({url : url, container : '#data_pjax', timeout: 0, scrollTo: companyHeader.offset().top});
#     }
#
#     dj.actions.topicsSelectToggle = function() {
#         const topic = $(this);
#         const selected = (topic.attr('data-selected') == 0 ? 1 : 0);
#
#         topic.attr('data-selected', selected);
#         topic.toggleClass('tags-new_selected', selected);
#
#         dj.actions.handleTopics();
#     }
#
#     dj.actions.handleTopics = function() {
#
#         const block = $('[data-js="topics-block"]');
#
#         const first_selected = $('#form_nrs').find('.js_selected_values_first_selected');
#
#         var arrSentiment0 = [];
#         var arrSentiment1 = [];
#
#         $('[data-id]', block).each(function() {
#             if (this.dataset.selected == 1) {
#                 const cont = $(this).closest('[data-sentiment]');
#                 const sentiment = cont.data('sentiment');
#
#                 if (sentiment == 0) {
#                     arrSentiment0.push(this.dataset.id)
#                 }
#                 if (sentiment == 1) {
#                     arrSentiment1.push(this.dataset.id)
#                 }
#             }
#         });
#
#         $('#nrs-topics_0').val(JSON.stringify(arrSentiment0));
#         $('#nrs-topics_1').val(JSON.stringify(arrSentiment1));
#
#         if (first_selected.val() === '' && (arrSentiment0.length !== 0 || arrSentiment1.length !== 0)) {
#             first_selected.val('topics');
#         }
#
#         if (first_selected.val() === 'topics' && arrSentiment0.length === 0 && arrSentiment1.length === 0) {
#             first_selected.val('');
#         }
#
#         let form = $('#form_nrs');
#         let url = form.attr('action');
#
#         let isFormNotEmpty = false;
#
#         for (let input of form.serializeArray()) {
#             if (input.value !== '[]' && input.value !== '' && input.id !== "nrs-first_selected") {
#                 isFormNotEmpty = true;
#                 break;
#             }
#         }
#
#         if (isFormNotEmpty && form.serialize()) {
#             url += '?' + form.serialize();
#         }
#
#         $.pjax({url : url, container : '#data_pjax', timeout: 0, scrollTo: companyHeader.offset().top});
#     }
#     $('[data-toggle="tooltip"]').tooltip({ customClass: 'tooltip--salary' });
# jQuery('#w0').yiiActiveForm([], []);
#     //открытие фильтра
#     $(document).on('change', '.dashboard-sidebar__rates-checkbox', function(e) {
#         e.preventDefault();
#         let data = $(this).parent('label').parent('div').find('input:checked');
#
#         const first_selected = $('#form_nrs').find('.js_selected_values_first_selected');
#
#         if (data.length) {
#
#             var arr = [];
#
#             $.each(data, function( key, value ) {
#                 let attribute = $(value).val();
#                 arr.push(attribute);
#             });
#
#             $('#nrs-ratings').val(JSON.stringify(arr));
#
#             if (first_selected.val() === '') {
#                 first_selected.val($(this).attr('data-attribute'));
#             }
#
#         } else {
#             $('#nrs-ratings').val(JSON.stringify([]));
#
#             if (first_selected.val() === $(this).attr('data-attribute')) {
#                 first_selected.val('');
#             }
#         }
#
#         let form = $('#form_nrs');
#         let url = form.attr('action');
#
#         let isFormNotEmpty = false;
#
#         for (let input of form.serializeArray()) {
#             if (input.value !== '[]' && input.value !== '') {
#                 isFormNotEmpty = true;
#                 break;
#             }
#         }
#
#         if (isFormNotEmpty && form.serialize()) {
#             url += '?' + form.serialize();
#         }
#
#         $.pjax({url : url, container : '#data_pjax', timeout: 0, scrollTo: true});
#     })
# jQuery('#w1').yiiActiveForm([], []);
# jQuery('#form_nrs').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery(document).pjax("#data_pjax_filters a", {"push":false,"replace":false,"timeout":0,"scrollTo":false,"container":"#data_pjax_filters"});
# jQuery(document).off("submit", "#data_pjax_filters form[data-pjax]").on("submit", "#data_pjax_filters form[data-pjax]", function (event) {jQuery.pjax.submit(event, {"push":false,"replace":false,"timeout":0,"scrollTo":false,"container":"#data_pjax_filters"});});
# jQuery(document).pjax("#data_pjax a", {"scrollOffset":-150,"push":true,"replace":true,"timeout":0,"scrollTo":true,"container":"#data_pjax"});
#
# $(document).on('click', '.pagination a', function (e) {
#     const page_number = $(this).data().page;
#     window.dj.stats.yandexGoal('pagination_review_next_page', {params: {page_number}});
# })
#
# const firstReview = $('.reviews__section [id^="review"]:first');
# //$('[data-partly-switch^="rating"]', firstReview).trigger('click');
# window.dj.core.onPartlySwitch(firstReview, firstReview);
# $('.tags', firstReview).removeClass('tags--collapsed');
#
# var anchor = $('[data-scroll-anchor="true"]');
# if (anchor.length === 1) {
#     anchor.attr('data-scroll-anchor', false);
#     $('body, html').animate({scrollTop: anchor.offset().top - 150}, 800);
# }
#
# $(document).off('click.data-review-helpful').on('click.data-review-helpful', '[data-review-helpful]', function (e) {
#     e.preventDefault();
#     $(this).addClass('_anim')
#     $(this).toggleClass('_active')
#     setTimeout(() => {
#         $(this).removeClass('_anim')
#     }, 500)
#
#     if (!$(this).data('wait')) {
#
#         var data;
#         let review_id = $(e.currentTarget).data('review-helpful');
#
#         $(this).data('wait', true);
#
#         (function (el) {
#             $.post('/review/recommend?id=' + review_id, function (res) {
#                 el.html(el.html().replace(/\d+/, res));
#             });
#         })($(this));
#
#         setTimeout(() => $(this).data('wait', false), 1000);
#     }
# });
#
#     $(document).on('click', '.js-shown-share', function(e) {
#         !$(this).find('.submenu.active').length ? $('.submenu.active').removeClass('active') : false;
#         $(this).find('.submenu').toggleClass('active');
#     })
#
#     $(document).on('scroll', function () {
#         $('.submenu').removeClass('active');
#     })
#
#     $(document).on('click', function(e) {
#         if (!$(e.target).closest('.submenu').length && !$(e.target).closest('.js-shown-share').length) {
#           $('.submenu').removeClass('active');
#         }
#     });
#
# var w2_data_1 = new Bloodhound({"datumTokenizer":Bloodhound.tokenizers.obj.whitespace('value'),"queryTokenizer":Bloodhound.tokenizers.whitespace,"remote":{"url":"/ajax/search-employer?q=%QUERY","wildcard":"%QUERY"}});
# kvInitTA('w2', typeahead_3fe4d359, [{"display":"value","limit":10,"templates":{"suggestion":(o) => (`<p data-reach-goal="search_companies_top_list">${o.text}</p>`)},"name":"w2_data_1","source":w2_data_1.ttAdapter()}]);
# jQuery("#w2").on('typeahead:select', window.dj.actions.companySearchSuggestClick);
# jQuery("#w2").on('typeahead:render', window.dj.actions.companySearchTypeaheadRender);
# jQuery("#w2").on('typeahead:asyncrequest', window.dj.actions.ttLoadingHandler);
# jQuery("#w2").on('typeahead:asynccancel', window.dj.actions.ttLoadingHandler);
# jQuery("#w2").on('typeahead:asyncreceive', window.dj.actions.ttLoadingHandler);
# jQuery('#search_form_header').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery('#w3').yiiActiveForm([], []);
# });</script>
# <script>jQuery(window).on('load', function () {
#    function vacanciesInjectWidget() {
#         const link = $('.vacanciesInjectWidget');
#         const url = link.attr('href');
#
#         if (url) {
#            $.ajax({
#                 url: url
#             }).done(function(html) {
#                 $('.vacanciesInjectWidgetContainer').html(html);
#             })
#         }
#     }
#
#     vacanciesInjectWidget();
# });</script> <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-26e44a76514b85cdf44","applicationID":"1111264889","transactionName":"YFxVZEUCCEVQBU1YXVkWdlNDCglYHgNUQV5YQFJCREwUU0cPXEZB","queueTime":0,"applicationTime":86,"atts":"TBtWEg0YG0s=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
title = soup0.find_all('div', {'class': 'company__name line-clamp-2'})[0].text.strip()
title
# Out:
# 'Розничная сеть МТС'

# %%
review = soup0.find_all('div', {'class': 'company__indicator-number'})[0].text.strip()
review
# Out:
# '3,3'

# %%
rec_share = soup0.find_all('div', {'class': 'company__indicator-number'})[1].text.strip()
rec_share
# Out:
# '48%'

# %%
review_cnts = soup0.find_all('span', {'class': 'tabs__count'})[0].text.strip().replace("\xa0", "")
review_cnts
# Out:
# '4012'

# %%
review_name = soup0.find_all('div', {'class': 'dashboard-sidebar__grade-humanly'})[0].text.strip()
review_name
# Out:
# 'Хорошо'

# %%
page1 = requests.get('https://dreamjob.ru/'+url0+'/career')
soup1 = BeautifulSoup(page1.text, 'html')
soup1
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1134516852",accountID:"4709628",trustKey:"4709628",xpid:"UAEHWFBRABABVVBTBQcDXlwI",licenseKey:"NRJS-26e44a76514b85cdf44",applicationID:"1111264889",browserID:"1134516852"};;/*! For license information please see nr-loader-spa-1.312.1.min.js.LICENSE.txt */
# (()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,Zm:()=>c,bQ:()=>u,dV:()=>d,pV:()=>l});var n=r(6154),i=r(1863),s=r(944),o=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function c(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function d(){let e=c();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,o.i)(...Object.values(e.o))),e}function u(e,t){let r=c();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t,2===Object.keys(r.initializedAgents).length&&(0,s.R)(69)}function l(){return function(){let e=c();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=c();const t=e.init||{};e.init={...t}}(),d(),function(){let e=c();const t=e.loader_config||{};e.loader_config={...t}}(),c()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>a,df:()=>s,qY:()=>n,v4:()=>o});const n="events",i="jserrors",s="browser/blobs",o="rum",a="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.softNav]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.sessionReplay]:8,[c.logging]:9,[c.genericEvents]:10},u={[c.pageViewEvent]:o,[c.pageViewTiming]:n,[c.ajax]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:a,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>o,TZ:()=>a,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},o="log",a=n.K7.logging},1541:(e,t,r)=>{"use strict";r.d(t,{$5:()=>d,B5:()=>c,Ux:()=>o,YA:()=>a,fQ:()=>i});var n=r(5871);const i={MFE:"MFE",BA:"BA"};function s(e,t){if(!e||!t?.init.api.allow_registered_children)return[];const r=t.runtime.registeredEntities;return r?.filter(t=>t.metadata.timings?.asset?.endsWith(e)).map(e=>e.metadata.target)||[]}function o(e,t){if(!u(t))return{};const r=t.agentRef.runtime.appMetadata.agents[0].entityGuid;return e?e.attributes:{"entity.guid":r,appId:t.agentRef.info.applicationID}}function a(e,t){return c(e,t)?{"child.id":e.id,"child.type":e.type,...o(void 0,t)}:{}}function c(e,t){return!!e&&!!u(t)&&t.agentRef.init.api.duplicate_registered_data}function d(e){if(!e?.init.api.allow_registered_children)return[void 0];const t=[];try{var r=(0,n.AZ)((0,n.QL)());let i=r.length-1;for(;r[i];)t.push(...s(r[i--],e))}catch(e){}return t.length||t.push(void 0),t}function u(e){return 2===e?.harvestEndpointVersion}},1687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>a,Ze:()=>d,x3:()=>c});var n=r(3241),i=r(3606),s=r(860),o=r(2646);function a(e,t){if(!e)return;const r={staged:!1,priority:s.P3[t]||0};e.runtime.drainRegistry.get(t)||e.runtime.drainRegistry.set(t,r)}function c(e,t){if(!e)return;const r=e.runtime.drainRegistry;r&&(r.get(t)&&r.delete(t),l(e,t,!1),r.size&&u(e))}function d(e,t="feature",r=!1){if(e){if(!e.runtime.drainRegistry.get(t)||r)return l(e,t);e.runtime.drainRegistry.get(t).staged=!0,u(e)}}function u(e){if(!e)return;const t=Array.from(e.runtime.drainRegistry);t.every(([e,t])=>t.staged)&&(t.so ...
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Карьера в Розничная сеть МТС ᐈ Преимущества и льготы в компании Розничная сеть МТС | Dream Job</title>
# <meta content="Карьера в Розничная сеть МТС ᐈ Преимущества и льготы в компании Розничная сеть МТС | Dream Job" property="og:title"/>
# <meta content="https://dreamjob.ru/employers/286960/career" property="og:url"/>
# <meta content="https://dreamjob.ru/i/dream-job.png" property="og:image"/>
# <meta content="Dream Job - крупнейший ресурс с отзывами сотрудников в России" property="og:image:alt"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1600" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Узнайте о льготах и преимуществах работы в компании Розничная сеть МТС. Подробная информация о карьере в Розничная сеть МТС на сайте Dream Job" name="description"/>
# <meta content="Узнайте о льготах и преимуществах работы в компании Розничная сеть МТС. Подробная информация о карьере в Розничная сеть МТС на сайте Dream Job" property="og:description"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.svg" rel="icon"/>
# <link href="https://dreamjob.ru/employers/286960/career" rel="canonical"/>
# <link href="/assets/10afff40/themes/smoothness/jquery-ui.min.css?v=1473979674" rel="stylesheet"/>
# <link href="/css/bs-4.6.1-dj.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/75dc149a/css/typeahead-kv.min.css?v=1559106416" rel="stylesheet"/>
# <link href="/assets/38b60184/css/kv-widgets.min.css?v=1654067138" rel="stylesheet"/>
# <link href="/css/roboto_font.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/general-styles.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/header-main.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/dj/pages/tab-career.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/css/dj/pages/tab-salary.min.css?v=1773644459" rel="stylesheet"/>
# <link href="/vendor/swiper/swiper-bundle.min.css?v=1773644461" rel="stylesheet"/>
# <link href="/assets/c3ae0fcc/css/centrifuge.css?v=1773644461" rel="stylesheet"/>
# <script src="/vendor/swiper/swiper-bundle.min.js?v=1773644461"></script>
# <script>window.typeahead_3fe4d359 = {"highlight":true,"minLength":2};
# </script>
# <script src="/js/fp_2_0_6.min.js"></script>
# <script>
#     Fingerprint2.get(function (cs) {
#         (function (w, d, s, l, i, c, fp, u, e, h) {
#             w[l] = w[l] || [];
#             w['fingerprint'] = {cs: cs, id: fp, uid: u, eid: e, hid: h};
#             w[l].push({fingerprint: fp});
#             if (u) w[l].push({user_id: u});
#             if (e) w[l].push({employer_id: e});
#             w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#             try {
#                 c = JSON.parse(c);
#                 for (let p of Object.keys(c)) {
#                     w[l].push({event: 'FlagAssigned', 'flag_id': p, 'flag_is_on': c[p]});
#                 }
#             } catch (e) {
#             }
#                         /* Google Tag Manager */
#
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#             /* End Google Tag Manager */
#                     })(window, document, 'script', 'dataLayer', 'GTM-M3XGKC6', '',
#             Fingerprint2.x64hash128(cs.map(function (pair) {
#                 return pair.value
#             }).join(), 31), 0);
#     });
# </script> <meta content="_csrf" name="csrf-param"/>
# <meta content="46p-aakiRSxYZGF3Xw7oiq-BOe51xeMz0geNigNHl6qE0wcZ4lZ0dQ8FVjMte4mz_ep_vhbz1WaLKuWzXAn2mw==" name="csrf-token"/>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3XGKC6" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script>var centrifugoOptions = {"wsConnectionEndpoint":"wss:\/\/centrifugo.dreamjob.ru:443\/connection\/websocket","connectionToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlMDMzYmRkODUxNmQ0NTg4ODZiZTE5NTgxZDZmZDBlYyJ9.fikkLyAzdRV3SI01O0ZLQeedBhJZbOfOtVBEf7LE2n4","subscriptionTokens":{"main-channel":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjaGFubmVsIjoibWFpbi1jaGFubmVsIiwic3ViIjoiZTAzM2JkZDg1MTZkNDU4ODg2YmUxOTU4MWQ2ZmQwZWMifQ.HCFTdw98RKddfFyDEVYUAcv2XpXTEeIQF2n4dGKPBug"},"userRoles":"guest","userId":"e033bdd8516d458886be19581d6fd0ec"};</script>
# <header class="header">
# <div class="container">
# <nav class="navbar navbar-expand-lg">
# <a class="dreamjob-logo__wrapper order-0" href="/" title="Главная Dream Job">
# <img alt="Dream Job логотип" class="dreamjob-logo__icon" src="/i/logo/logo.svg"/>
# <img alt="Dream Job название компании" class="dreamjob-logo__name" src="/i/logo/brand.svg"/>
# </a>
# <a class="monthly-award-tag" data-event-click='{"event_id":4,"scenario":"employer_month","event_type":1}' data-event-show='{"event_id":3,"scenario":"employer_month","event_type":1}' href="/company-month">
# <img alt="" class="monthly-award-tag__logo" src="/images/icons/month-company/ears-of-wheat_sm.svg"/>
# <span class="monthly-award-tag__text">Компания месяца</span>
# </a>
# <div class="input-group mob_input md-form form-sm form-2 d-lg-none order-3" id="headerMobSearch">
# <button class="header__btn-close reset-button" data-action="toggleClass" data-class="open_inp" data-target="#headerMobSearch" type="button">
# <svg class="rc__tLLGP" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M20 0v20V0ZM0 20V0v20Zm8.116-3.823-5.469-5.47a.999.999 0 0 1 0-1.414l5.469-5.47a.5.5 0 0 1 .707 0l.354.354a.5.5 0 0 1 0 .707L4.811 9.25H17.5a.5.5 0 0 1 .5.5v.5a.5.5 0 0 1-.5.5H4.811l4.366 4.366a.5.5 0 0 1 0 .707l-.354.354a.5.5 0 0 1-.707 0Z" fill="#3460A4" fill-rule="evenodd"></path>
# </svg>
# </button>
# <form action="/site/search" class="tt__wrap" id="search_form_header" method="get"> <div class="tt-scrollable-menu"><input aria-label="Search" autocomplete="off" class="form-control input-field" data-input-action="ttInputHandlerTopSearch" data-krajee-typeahead="typeahead_3fe4d359" id="w1" name="query" placeholder="Введите название компании" type="text"/></div>
# <button class="header__button-find reset-button" data-reach-goal="search_companies_top_button" type="submit"></button>
# <div class="tt__clear" data-action="ttClear"></div>
# </form>
# </div>
# <a class="header-button header-button--search d-lg-none order-2" data-action="headerSearchOpen" href="javascript:void(0)" role="button" title="Поиск компаний"></a>
# <!--            <a href="-->
# <!--" class="order-2 header-button header-button--vacancies d-lg-none"-->
# <!--               title="Вакансии" data-action="gaPush"-->
# <!--               data-layer-push='{"event":"vacancies_name_click"}' data-reach-goal="vacancies_top_button_click"-->
# <!--               data-event-click='-->
# <!--'-->
# <!--            >-->
# <a class="order-2 header-button header-button--wallet d-lg-none" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary" title="Зарплаты">
# </a>
# <!-- --> <div aria-controls="navContent" aria-expanded="false" class="bt icon-bg-burger reset-button d-lg-none order-2 collapsed" data-target="#navContent" data-toggle="collapse" role="button"></div>
# <div class="collapse navbar-collapse order-3" id="navContent">
# <!--               <div style="flex: 1 0;" class="input-group md-form form-sm form-2 pl-0 header__search-form d-none d-lg-block">-->
# <!--                   <form method="get" class="tt__wrap" action="-->
# <!--">-->
# <!-- --> <!--                        <button class="header__button-find reset-button" type="submit" data-reach-goal="search_companies_top_button"></button>-->
# <!--                        <div class="tt__clear" data-action="ttClear"></div>-->
# <!--                    </form>-->
# <!--               </div>-->
# <div class="header__buttons">
# <!--                    <a class="monthly-award-tag">-->
# <!--                        <img class="monthly-award-tag__logo logo" src="/images/icons/recommendations/ears-of-wheat.svg" alt="">-->
# <!--                        <span class="monthly-award-tag__text text">Компания месяца</span>-->
# <!--                    </a>-->
# <a class="header-button header-button--search d-none d-lg-block" href="/#search">
#                                 Поиск
#                             </a>
# <a class="header-button header-button--vacancies d-none d-lg-block" data-action="gaPush" data-event-click='{"event_id":24,"scenario":"jb"}' href="/vakansii">
#                                 Вакансии
#                             </a>
# <a class="header-button header-button--wallet d-none d-lg-block" data-action="gaPush" data-layer-push='{"event":"salary_name_click"}' data-reach-goal="salary_top_button_click" href="/salary">
#                                 Зарплаты
#                             </a>
# <a class="header-button header-button--for-employer d-none d-lg-block" href="/page/employers">Работодателям</a>
# <a class="header-button header-button--user d-none d-lg-block" href="/site/login">Войти</a>
# <div class="mob_menu d-lg-none js-modile-menu">
# <div class="inner-menu">
# <div class="inner_block-menu">
# <ul>
# <li class="month-company__burger-menu-item">
# <a class="bt body2r bt--primary-link icon-bg-ears-of-wheat_rounding" data-event-click='{"event_id":6,"scenario":"employer_month"}' data-event-show='{"event_id":5,"scenario":"employer_month"}' href="/company-month">Компания месяца</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-vacancies" href="/vakansii">Вакансии</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-wallet" href="/salary">Зарплаты</a></li>
# <li><a class="bt body2r bt--primary-link icon-bg-bag" href="/page/employers">Работодателям</a>
# </li>
# <li><a class="bt body2r bt--primary-link icon-bg-profile" href="/site/login">Вход в личный кабинет</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div class="company-header" data-employer-id="286960" data-js="employerHeader">
# <div class="banner mobileBannerExist">
# <div class="container">
# <img alt="баннер Розничная сеть МТС" class="old-banner show-mobile-old-banner img-default" src="https://cdn.dreamjob.ru/employer/286960/675c8cbcb0071MTzc-X.png"/>
# </div>
# <div class="show-desktop-old-banner">
# <div class="container">
# <div class="default-banner">
# <a class="banner__button bt bt--32 bt--primary-outline" data-action="gaPush" data-layer-push='{"event":"Manage_Employer_Profile_Click"}' href="/page/employers">
#         Управлять профилем работодателя
#     </a>
# </div>
# </div>
# </div>
# </div>
# <div class="company-header__info">
# <div class="company-header__info_top">
# <div class="container-md">
# <div class="company">
# <div class="company__block">
# <div class="company__logo">
# <a class="company__link-img" href="/employers/286960" title="Розничная сеть МТС">
# <img alt="Розничная сеть МТС отзывы сотрудников" class="company__img-logo" src="https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png"/>
# </a>
# </div>
# <div class="company__name_wrap">
# <div class="company__name line-clamp-2" data-js="companyName">
#                                     Розничная сеть МТС                                </div>
# <div class="company__open d-none d-md-flex" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="company__indicators">
# <div class="company__indicator company__rating d-md-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">3,3</div>
# <div class="dj-rating86 dj-rating86_no-value dj-rating86--30"></div>
# </div>
# <div class="company__indicator-text">Хорошо</div>
# </div>
# <div class="company__indicator company__recommend d-none d-lg-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">48%</div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:47.63%;"></div>
# </div>
# </div>
# <div class="company__indicator-text">Рекомендуют</div>
# </div>
# <div class="company__open ml-0 d-md-none" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="company__buttons">
# <a class="bt bt--success d-md-none company__buttons-add" data-action="gaPush" data-event-click='{"event_id":7,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960" id="write_review_mobile">
#                                     Оставить отзыв
#                                 </a>
# <a class="bt bt--soft-outline d-md-none company__buttons-compare" data-event-click='{"event_id":8,"scenario":"employer_public","employer_id":286960}' data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#                                     Сравнить
#                                 </a>
# </div>
# </div>
# </div>
# <div class="company fixed-company-hidden">
# <div class="company__block" id="topPage">
# <div class="company__logo logo--88-64">
# <span class="logo" style="background-image: url('https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png')"></span>
# </div>
# <div class="company__name_wrap">
# <div class="company__name line-clamp-2" data-js="companyName">
#                                     Розничная сеть МТС                                </div>
# <div class="company__open d-none d-md-flex" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="company__indicators">
# <div class="company__indicator company__rating d-md-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">3,3</div>
# <div class="dj-rating86 dj-rating86_no-value dj-rating86--30"></div>
# </div>
# <div class="company__indicator-text">Хорошо</div>
# </div>
# <div class="company__indicator company__recommend d-none d-lg-block">
# <div class="company__indicator-value">
# <div class="company__indicator-number">48%</div>
# <div class="rate__item-progress">
# <div class="rate__item-progress-value" style="width:47.63%;"></div>
# </div>
# </div>
# <div class="company__indicator-text">Рекомендуют</div>
# </div>
# <div class="company__open ml-0 d-md-none" data-company-popup-wrapper="">
# <div class="company__open-badge-wrapper">
# <div class="company__open-badge" data-company-popup-show="">Открытый работодатель</div>
# <div class="company__open_popup js-tooltip-employers" data-company-popup="">
# <div class="company__open_popup_close d-md-none" data-company-popup-close=""></div>
# <div class="company__open_popup_inner">
# <p>Работодатель является лидером по открытости на рынке труда и вниманию к мнению сотрудников.</p>
# <p>Системная работа с отзывами сотрудников поддерживает прозрачность рынка труда и развивает HR-бренд работодателя.</p>
# <p>Ваша компания хочет так же? <a class="link-wrapper" href="/page/employers">Подробнее</a></p>
# <p class="icon-circle">Мы не удаляем отзывы по требованию работодателей.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="company__buttons">
# <a class="bt bt--success d-md-none company__buttons-add" data-action="gaPush" data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960" id="write_review_header">
#                                     Оставить отзыв
#                                 </a>
# <a class="bt bt--soft-outline d-md-none company__buttons-compare" data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#                                     Сравнить
#                                 </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="awards awards__modal d-none">
# <div class="awards-track awards-track__dashboard">
# <div class="awards-track__header">
# <div class="awards-track__header-wrapper">
# <span class="awards-track__heading">Награды компании</span>
# <span class="awards-track__quantity">0 наград из 4</span>
# </div>
# <span class="awards__modal-close-button" data-event-click='{"event_id":17,"scenario":"award"}'></span>
# </div>
# <div class="awards-carts awards-carts__wrapper flex-wrap">
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Лидер обратной связи">
# <span class="awards-carts__heading">Лидер обратной связи</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:8%"></div>
# </div>
# <span class="awards-carts__in-progress-label">8% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_messages"></span>
# <span class="awards-carts__information">Есть у 1% компаний на Dream Job</span>
# <p class="awards-carts__text">Компания поддерживает открытый диалог с сотрудниками, оперативно отвечая на каждый отзыв</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Забота о сотрудниках">
# <span class="awards-carts__heading">Забота о сотрудниках</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:57%"></div>
# </div>
# <span class="awards-carts__in-progress-label">57% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_hurt"></span>
# <span class="awards-carts__information">Есть у 1.1% компаний на Dream Job</span>
# <p class="awards-carts__text">Работодатель поддерживает достойные условия труда и отдыха для сотрудников</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Карьерный рост">
# <span class="awards-carts__heading">Карьерный рост</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:82%"></div>
# </div>
# <span class="awards-carts__in-progress-label">82% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_uptrand"></span>
# <span class="awards-carts__information">Есть у 1.8% компаний на Dream Job</span>
# <p class="awards-carts__text">В компании есть возможности для карьерного и профессионального роста сотрудников</p>
# </div>
# <div class="awards-carts__item awards-carts__item_not-reached" data-title="Корпоративная культура">
# <span class="awards-carts__heading">Корпоративная культура</span>
# <span class="awards-carts__reached-label">Получена: 06.04.2026 </span>
# <div class="awards-carts__in-progress awards-carts__in-progress-wrapper">
# <div class="progress">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="75" class="progress-bar" role="progressbar" style="width:84%"></div>
# </div>
# <span class="awards-carts__in-progress-label">84% выполнено</span>
# </div>
# <span class="awards-carts__icon awards-carts__icon_handshake"></span>
# <span class="awards-carts__information">Есть у 2.8% компаний на Dream Job</span>
# <p class="awards-carts__text">Сотрудники отмечают профессионализм руководства и хорошую атмосферу в коллективе</p>
# </div>
# </div>
# </div>
# </div>
# <div class="sticky-block js-sticky-block">
# <div class="container-md" data-js="employerTabs">
# <div class="tabs" data-behavior="tabs">
# <a class="tabs__item tabs__item_career _active" data-ajax-tab="site_employer_career" data-event-click='{"event_id":1,"scenario":"employer_public","employer_id":286960}' href="/employers/286960/career" id="tab_career">
# <span class="tabs__text">О компании</span>
# </a>
# <a class="tabs__item" data-action="gaPush" data-ajax-tab="site_employer_reviews" data-event-click='{"event_id":2,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"reviews"}' data-reach-goal="tab_reviews" href="/employers/286960" id="tab_reviews">
# <span class="tabs__text">Отзывы </span>
# <span class="tabs__count">4 012</span>
# </a>
# <a class="tabs__item tabs__item_vacancies" data-event-click='[{"event_id":1,"scenario":"jb","employer_id":286960},{"event_id":3,"scenario":"employer_public","employer_id":286960}]' href="/employers/286960/vakansii" id="tab_vacancies-new">
# <span class="tabs__text">Вакансии </span>
# <span class="tabs__count">626</span>
# </a>
# <a class="tabs__item" data-action="gaPush" data-ajax-tab="site_employer_salary" data-event-click='{"event_id":4,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"salary"}' data-reach-goal="tab_salary" href="/employers/286960/zarplata" id="tab_salary">
# <span class="tabs__text">Зарплаты </span>
# <span class="tabs__count">1 596</span>
# </a>
# <a class="tabs__item" data-action="gaPush" data-ajax-tab="site_employer_interviews" data-event-click='{"event_id":5,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Tab_Click","tab":"interviews"}' data-reach-goal="dj_interviews" href="/employers/286960/interviews" id="tab_interviews">
# <span class="tabs__text">Собеседования </span>
# <span class="tabs__count">113</span>
# </a>
# <a class="bt-master bt-master_blue d-none d-md-inline-flex" data-action="gaPush" data-event-click='{"event_id":7,"scenario":"employer_public","employer_id":286960}' data-layer-push='{"event":"Add_Review_Click"}' href="/add?employer_id=286960">
#             Оставить отзыв
#         </a>
# <a class="bt-40 d-none d-xl-inline-flex" data-event-click='{"event_id":8,"scenario":"employer_public","employer_id":286960}' data-reach-goal="compare_button_page_top" href="/employers/compare?employer_id=286960&amp;init_id=286960">
#             Сравнить
#         </a>
# </div>
# </div>
# </div>
# <main class="career" data-event-page-closed='{"event_id":17,"scenario":"employer_public","event_type":1,"employer_id":286960}' data-event-page-loaded='{"event_id":16,"scenario":"employer_public","event_type":1,"employer_id":286960}' data-full-scripts="employer.tabCareerScript" data-partial-scripts="core.initSliders|core.initVideos|core.initScrollTriggers|employer.tabCareerScript" id="site_employer_career">
# <div class="container reviews">
# <h1 class="career__title">Карьера в Розничная сеть МТС</h1>
# <div class="career__section">
# <div class="row">
# <div class="col-lg-8 career__section_block career__ratings">
# <div class="ratings block">
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">3,4</div>
# <div class="ratings__item-title">Условия труда</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:67%;"></div>
# </div>
# <div class="ratings__item-text">Хорошо</div>
# </div>
# </div>
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">2,8</div>
# <div class="ratings__item-title">Уровень дохода</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:56.8%;"></div>
# </div>
# <div class="ratings__item-text">Нормально</div>
# </div>
# </div>
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">4,2</div>
# <div class="ratings__item-title">Коллектив</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:84%;"></div>
# </div>
# <div class="ratings__item-text">Очень хорошо</div>
# </div>
# </div>
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">3,2</div>
# <div class="ratings__item-title">Руководство</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:63.6%;"></div>
# </div>
# <div class="ratings__item-text">Хорошо</div>
# </div>
# </div>
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">2,8</div>
# <div class="ratings__item-title">Условия для отдыха</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:56.2%;"></div>
# </div>
# <div class="ratings__item-text">Нормально</div>
# </div>
# </div>
# <div class="ratings__item">
# <div class="ratings__item-header">
# <div class="ratings__item-value">3,5</div>
# <div class="ratings__item-title">Возможности роста</div>
# </div>
# <div class="ratings__item-detail">
# <div class="ratings__item-progress">
# <div class="ratings__item-progress-value" style="width:69.4%;"></div>
# </div>
# <div class="ratings__item-text">Хорошо</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-4 career__section_block">
# <div class="recommendation-block">
# <h2 class="recommendation-block__title">Отзывы сотрудников</h2>
# <div class="recommendation-block__value">48%</div>
# <div class="recommendation-block__text">рекомендуют эту компанию для трудоустройства (на
#                                 основе 4 012 оценок)
#                             </div>
# <a class="bt bt--primary-link icon-arrow-right icon--right" data-action="click" data-target="#tab_reviews" href="/employers/286960">
#                                 Узнать больше
#                             </a>
# </div>
# </div>
# </div>
# </div>
# <div class="career__section career-benefits">
# <h2>Преимущества и льготы в компании</h2>
# <p>Сотрудники чаще всего указывали следующие льготы и преимущества на основании 4 012 отзывов</p>
# <div class="career-benefits__content">
# <div class="career__section_block">
# <div class="benefits-with-indicator" data-benefits="">
# <div class="benefits-with-indicator__items row no-gutters">
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--1"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Своевременная оплата труда</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:74%;"></div>
# </div>
# <div class="benefit-with-indicator__value">74%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--2"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Удобное расположение работы</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:57%;"></div>
# </div>
# <div class="benefit-with-indicator__value">57%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--3"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Удаленная работа</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:5%;"></div>
# </div>
# <div class="benefit-with-indicator__value">5%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--4"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Наличие кухни, места для обеда</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:19%;"></div>
# </div>
# <div class="benefit-with-indicator__value">19%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--5"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Медицинское страхование</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:36%;"></div>
# </div>
# <div class="benefit-with-indicator__value">36%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--6"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Оплата больничного</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:62%;"></div>
# </div>
# <div class="benefit-with-indicator__value">62%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--7"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Гибкий рабочий график</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:41%;"></div>
# </div>
# <div class="benefit-with-indicator__value">41%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--8"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Компенсация питания</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:1%;"></div>
# </div>
# <div class="benefit-with-indicator__value">1%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--9"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Оплата транспортных расходов</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:3%;"></div>
# </div>
# <div class="benefit-with-indicator__value">3%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--10"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Корпоративный транспорт</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:2%;"></div>
# </div>
# <div class="benefit-with-indicator__value">2%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--11"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Профессиональное обучение</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:36%;"></div>
# </div>
# <div class="benefit-with-indicator__value">36%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--12"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Место для парковки</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:3%;"></div>
# </div>
# <div class="benefit-with-indicator__value">3%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--13"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Оплата мобильной связи</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:25%;"></div>
# </div>
# <div class="benefit-with-indicator__value">25%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--14"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Система наставничества</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:28%;"></div>
# </div>
# <div class="benefit-with-indicator__value">28%</div>
# </div>
# </div>
# </div>
# <div class="benefits-with-indicator__item col-12 col-md-6 col-lg-5 col-xl-4" data-benefits-item="">
# <div class="benefit-with-indicator dj--accordion">
# <div class="benefit-with-indicator__icon benefit-with-indicator__icon--15"></div>
# <div class="benefit-with-indicator__content">
# <div class="benefit-with-indicator__title">Корпоративные мероприятия</div>
# <div class="benefit-with-indicator__progress">
# <div class="benefit-with-indicator__progress_active" style="width:25%;"></div>
# </div>
# <div class="benefit-with-indicator__value">25%</div>
# </div>
# </div>
# </div>
# </div>
# <div class="career-benefits__btn">
# <button class="toggle-btn" data-action="benefitsToggle">
# <span class="toggle-btn__text _show">Раскрыть список</span>
# <span class="toggle-btn__text _hide">Скрыть</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="career__section career__section_border">
# <h2 id="blockCareer">О компании</h2>
# <div class="career__about">
# <div class="row career__about-items">
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Сайт компании</div>
# <form action="/employers/show-site" id="w0" method="post" target="_blank">
# <input name="_csrf" type="hidden" value="46p-aakiRSxYZGF3Xw7oiq-BOe51xeMz0geNigNHl6qE0wcZ4lZ0dQ8FVjMte4mz_ep_vhbz1WaLKuWzXAn2mw=="/>
# <input name="employer_id" type="hidden" value="286960"/>
# <span onclick="$(this).closest('form').submit()" style="cursor: pointer; color: #3460a4">
#                         Перейти                    </span>
# </form>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Количество сотрудников</div>
# <p>более 10000</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Город (головной офис)</div>
# <p>Москва</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Год основания</div>
# <p>2001</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Отрасль</div>
# <p>Розничная торговля</p>
# </div>
# </div>
# <div>
# <div data-toggle="line-clamp-off">
# <div class="text-16 line-clamp-4"> Розничная сеть МТС – самый быстрый способ познакомиться с нашими продуктами и сервисами. Мы развиваем интернет-магазин с доставкой по России и почти 4000 офлайн магазинов, где можно подключить услуги МТС и найти все: от сим-карт до технологичных гаджетов. А еще это легкий старт карьеры в большой экосистеме. </div>
# <button class="toggle-btn ghost" data-toggle-btn="Скрыть">Читать дальше</button>
# </div>
# </div>
# </div>
# </div>
# <div class="career__section career__stories" id="employee_stories">
# </div>
# </div>
# </main>
# <footer class="footer">
# <div class="footer__container">
# <div class="footer__grid">
# <div class="footer__card">
# <a aria-controls="collapseOne" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseOne" id="headingOne" role="button">
#                     Соискателям
#                 </a>
# <div aria-labelledby="headingOne" class="footer__collapse collapse" id="collapseOne">
# <a class="footer__link footer__link_hover" href="/applicant2/reviews/index">
#                         Личный кабинет
#                     </a>
# <a class="footer__link footer__link_hover" href="/anonym">
#                         Гарантия анонимности
#                     </a>
# <a class="footer__link footer__link_hover" href="/salary">
#                         Зарплаты
#                     </a>
# <a class="footer__link footer__link_hover" href="/vakansii">
#                         Вакансии
#                     </a>
# <a class="footer__link footer__link_hover" href="/categories">
#                         Компании по категориям
#                     </a>
# <a class="footer__link footer__link_hover" href="/add">
#                         Оставить отзыв
#                     </a>
# </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseTwo" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseTwo" id="headingTwo" role="button">
#                     Работодателям
#                 </a>
# <div aria-labelledby="headingTwo" class="footer__collapse collapse" id="collapseTwo">
# <a class="footer__link footer__link_hover" data-reach-goal="click_employer_profile" href="/employer">
#                         Личный кабинет
#                     </a>
# <a class="footer__link footer__link_hover" data-reach-goal="click_platform_potential" href="/page/employers">
#                         Возможности платформы
#                     </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-copyright.pdf" target="_blank">
# <span>Гайд по копирайтингу</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-visual.pdf" target="_blank">
# <span>Гайд по брендингу</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-reviews-collect.pdf" target="_blank">
# <span>Гайд по сбору отзывов</span>
# </a>
# <a class="footer__link footer__link_arrow footer__link_hover" href="/guides/guide-widget.pdf" target="_blank">
# <span>Виджет на сайт</span>
# </a>
# <a class="footer__link footer__link_hover" href="/employers/258089/blog/apdejt-po-pilotu-korporativnyh-blogov-na-dream-job">
#                         Корпоративные блоги
#                     </a>
# <a class="footer__link footer__link_hover" data-reach-goal="click_add_company" href="/site/register?role=employer_admin">
#                             Добавить компанию
#                         </a>
# <form action="/site/show-hj" id="w2" method="post" target="_blank">
# <input name="_csrf" type="hidden" value="46p-aakiRSxYZGF3Xw7oiq-BOe51xeMz0geNigNHl6qE0wcZ4lZ0dQ8FVjMte4mz_ep_vhbz1WaLKuWzXAn2mw=="/> <span class="footer__link footer__link_hover" onclick="$(this).closest('form').submit()">
#                             Dream Job + Happy Job
#                         </span>
# </form> </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseThree" aria-expanded="true" class="footer__title footer__title_border collapsed" data-toggle="collapse" href="#collapseThree" id="headingThree" role="button">
#                     О Dream Job
#                 </a>
# <div aria-labelledby="headingThree" class="footer__collapse footer__collapse_border collapse" id="collapseThree">
# <a class="footer__link footer__link_hover" href="/employers/258089/career#blockCareer">
#                         О проекте
#                     </a>
# <a class="footer__link footer__link_hover" href="/principles">
#                         Правила и принципы
#                     </a>
# <a class="footer__link footer__link_hover" href="/license-agreement">
#                         Пользовательское соглашение
#                     </a>
# <a class="footer__link footer__link_hover" href="/privacy">
#                         Политика конфиденциальности
#                     </a>
# <a class="footer__link footer__link_hover" href="/it-activity">
#                         Деятельность в IT-сфере
#                     </a>
# <a class="footer__link footer__link_hover" href="/article/software ">
#                         Реестр ПО РФ
#                     </a>
# <a class="footer__link footer__link_hover" data-event-click='{"event_id":350,"scenario":"lkr"}' href="/release-notes ">
#                         Что нового на Dream Job
#                     </a>
# </div>
# <a aria-controls="collapseFour" aria-expanded="true" class="footer__title mt-md-5 collapsed" data-toggle="collapse" href="#collapseFour" id="headingFour" role="button">
#                     Адрес
#                 </a>
# <div aria-labelledby="headingFour" class="footer__collapse collapse" id="collapseFour">
# <span class="footer__link">ООО «ДРИМ ДЖОБ»</span>
# <span class="footer__link">улица Искры, д. 17А, стр. 3,<br/> Москва, 129344, Россия</span>
# <span class="footer__link">ИНН 7707450945 <br/> ОГРН 1217700149590</span>
# </div>
# </div>
# <div class="footer__card">
# <a aria-controls="collapseFive" aria-expanded="true" class="footer__title collapsed" data-toggle="collapse" href="#collapseFive" id="headingFive" role="button">
#                     Связаться с нами
#                 </a>
# <div aria-labelledby="headingFive" class="footer__collapse collapse" id="collapseFive">
# <a class="footer__link footer__link_hover" href="/contacts">Контакты / Пресс-центр</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/career#photoCompany">Команда</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/vakansii">Вакансии</a>
# <a class="footer__link footer__link_hover" href="/employers/258089/blog">Блог Dream Job</a>
# </div>
# </div>
# <div class="footer__card footer__card_left">
# <a class="footer__title">
#                     Служба поддержки
#                 </a>
# <div class="footer__collapse">
# <span class="footer__link">График работы:</span>
# <span class="footer__link">Понедельник-пятница, <br/> с 9 до 18 по Москве.</span>
# <div>
# <span class="footer__link footer__link_mail">Для работодателей:</span>
# <a class="footer__mail" href="mailto:employers@dreamjob.ru">employers@dreamjob.ru</a>
# </div>
# <div>
# <span class="footer__link footer__link_mail">Для соискателей:</span>
# <a class="footer__mail" href="mailto:info@dreamjob.ru">info@dreamjob.ru</a>
# </div>
# <a class="footer__telegram" href="https://t.me/+-CLt0jp2KOUzOWIy" rel="nofollow noopener noreferrer" target="_blank" title="Dream Job в телеграмм">
#                         Мы в телеграм
#                     </a>
# </div>
# </div>
# </div>
# <div class="footer__info">
# <div class="footer-top">
# <p class="footer__text">Dream Job — крупнейший в России сайт отзывов сотрудников,
#                     нам доверяют более 7 000 000 пользователей ежемесячно.</p>
# <p class="footer__text">
#                     Миссия платформы — делать рынок труда в России прозрачнее и справедливее,
#                     помогать людям находить работу, а компаниям — становиться лучшими работодателями.
#                 </p>
# </div>
# <div class="footer-bottom">
# <p class="footer__text">
#                     Dream Job использует файлы cookie с целью безопасности, а также
#                     оптимизации и персонализации сервисов и повышения удобства пользования сайтом.
#                     Cookie представляют собой небольшие файлы, содержащие информацию о предыдущих посещениях сайта.
#                     Если вы не хотите использовать файлы cookie, измените настройки браузера.
#                 </p>
# <p class="footer__text">
#                     Свидетельство на товарный знак № 914157 от 09.01.2023 г
#                     <br/>
#                     © 2026. ООО "Дрим Джоб". Все права защищены.
#                 </p>
# </div>
# <div class="footer-middle">
# <!--dj rating-->
# <a href="https://dreamjob.ru/employers/258089" rel="noopener" target="_blank"><img alt="Dream Job отзывы сотрудников о работодателе на Dream Job" data-id="wg-258089-1-1" height="114" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg'%3E%3C/svg%3E" style="border:0" title="Рейтинг работодателя на Dream Job" width="170"/>
# </a>
# <script>(function (s) {
#                     document.querySelectorAll("[data-id=wg-258089-1-1]").forEach(function (e) {
#                       e.src = s
#                     })
#                   }("https://dreamjob.ru/widget/light?employer_id=258089"))</script>
# <!--/dj rating-->
# </div>
# </div>
# </div>
# </footer>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Organization","name":"Розничная сеть МТС","alternateName":"Розничная сеть МТС","url":"https://job.mts.ru/vacancies/salony-prodazh","logo":"https://cdn.dreamjob.ru/employer/286960/675c8cbcd4518VpxH4S.png"}</script>
# <script src="/assets/5e8b9362/jquery.min.js?v=1693204750"></script>
# <script src="/assets/84fcf258/yii.js?v=1767968650"></script>
# <script src="/assets/10afff40/jquery-ui.min.js?v=1473979674"></script>
# <script src="/assets/a0ab202/js/bootstrap.bundle.min.js?v=1773644475"></script>
# <script src="/assets/75dc149a/js/typeahead.bundle.min.js?v=1559106416"></script>
# <script src="/assets/75dc149a/js/typeahead-kv.min.js?v=1559106416"></script>
# <script src="/assets/38b60184/js/kv-widgets.min.js?v=1654067138"></script>
# <script src="/js/dj_data_save.js?v=1773644461"></script>
# <script src="/js/loader.min.js?v=1775227568"></script>
# <script src="/js/mobileScrollToTabs.js?v=1773644461"></script>
# <script src="/js/employers/tooltip-new.js?v=1773644461"></script>
# <script src="/js/site-employer.min.js?v=1773644461"></script>
# <script src="/js/employer.js?v=1773644461"></script>
# <script src="/js/awards.js?v=1773644461"></script>
# <script src="/js/jquery.cookie.js?v=1773644461"></script>
# <script src="/assets/84fcf258/yii.activeForm.js?v=1767968650"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/centrifuge/5.2.0/centrifuge.min.js"></script>
# <script src="/assets/c3ae0fcc/js/centrifuge.js?v=1773644461"></script>
# <script src="/js/set-focus-on-search.js?v=1773644461"></script>
# <script src="/js/mobile-header-logo-switcher.js?v=1773644461"></script>
# <script>jQuery(function ($) {
#
# //всплывашка "Открытый работодатель" TODO переделать bs popups
# const initPopups = function() {
#
#     const sPopups = $('[data-company-popup-wrapper]:not(.js-initialized)').addClass('js-initialized');
#
#     if (sPopups.length == 0) {
#         return
#     }
#
#     sPopups.each(function () {
#         const
#             sShow = $(this).find('[data-company-popup-show]'),
#             sClose = $(this).find('[data-company-popup-close]'),
#             sContent = $(this).find('[data-company-popup]');
#
#         sShow.on('click', function () {
#             //sContent.addClass('_open');
#             if ($(document).scrollTop()>575) {
#                 sContent.removeClass('_open');
#             } else{
#                 sContent.addClass('_open');
#             }
#         });
#
#         sClose.on('click', function () {
#             sContent.removeClass('_open');
#         });
#     });
#
#     $(document).click(function (e) {
#         sPopups.each(function () {
#             if (!$(e.target).closest($(this)).length) {
#                 $(this).find('[data-company-popup]').removeClass('_open')
#             }
#         });
#     });
# }
#
# initPopups();
#
#
# // const div_fixed = $(".company__bottom-btns");
# // const div_close = $(".icon-times-1");
# // const windowInnerHeight = window.innerHeight;
# //
# // if (div_fixed.length) {
# //
# //     //div_fixed.find('a').click(e => $.cookie('hide-bottom-buttons', true));
# //
# //     //if (!$.cookie('hide-bottom-buttons')) {
# //
# //         $(window).scroll(function(){
# //             if ($(window).scrollTop()>windowInnerHeight) {
# //                 div_fixed.css("display", "flex");
# //             } else {
# //                 div_fixed.css("display", "none");
# //             }
# //         });
# //
# //     //}
# // }
#
# // div_close.click(function(){
# //       div_fixed.addClass("d-none");
# //       // window.innerHeight = windowInnerHeight;
# //  });
#
# jQuery('#w0').yiiActiveForm([], []);
# jQuery&&jQuery.pjax&&(jQuery.pjax.defaults.maxCacheLength=0);
# var w1_data_1 = new Bloodhound({"datumTokenizer":Bloodhound.tokenizers.obj.whitespace('value'),"queryTokenizer":Bloodhound.tokenizers.whitespace,"remote":{"url":"/ajax/search-employer?q=%QUERY","wildcard":"%QUERY"}});
# kvInitTA('w1', typeahead_3fe4d359, [{"display":"value","limit":10,"templates":{"suggestion":(o) => (`<p data-reach-goal="search_companies_top_list">${o.text}</p>`)},"name":"w1_data_1","source":w1_data_1.ttAdapter()}]);
# jQuery("#w1").on('typeahead:select', window.dj.actions.companySearchSuggestClick);
# jQuery("#w1").on('typeahead:render', window.dj.actions.companySearchTypeaheadRender);
# jQuery("#w1").on('typeahead:asyncrequest', window.dj.actions.ttLoadingHandler);
# jQuery("#w1").on('typeahead:asynccancel', window.dj.actions.ttLoadingHandler);
# jQuery("#w1").on('typeahead:asyncreceive', window.dj.actions.ttLoadingHandler);
# jQuery('#search_form_header').yiiActiveForm([], {"validateOnSubmit":false});
# jQuery('#w2').yiiActiveForm([], []);
# });</script> <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-26e44a76514b85cdf44","applicationID":"1111264889","transactionName":"YFxVZEUCCEVQBU1YXVkWdlNDCglYHgNUQV5YQFJCREwFV0MDXEM=","queueTime":1,"applicationTime":49,"atts":"TBtWEg0YG0s=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
about = soup1.find('div', {'class': 'row career__about-items'})
about
# Out:
# <div class="row career__about-items">
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Сайт компании</div>
# <form action="/employers/show-site" id="w0" method="post" target="_blank">
# <input name="_csrf" type="hidden" value="46p-aakiRSxYZGF3Xw7oiq-BOe51xeMz0geNigNHl6qE0wcZ4lZ0dQ8FVjMte4mz_ep_vhbz1WaLKuWzXAn2mw=="/>
# <input name="employer_id" type="hidden" value="286960"/>
# <span onclick="$(this).closest('form').submit()" style="cursor: pointer; color: #3460a4">
#                         Перейти                    </span>
# </form>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Количество сотрудников</div>
# <p>более 10000</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Город (головной офис)</div>
# <p>Москва</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Год основания</div>
# <p>2001</p>
# </div>
# <div class="col-md-6 col-lg-4 career__about-item">
# <div>Отрасль</div>
# <p>Розничная торговля</p>
# </div>
# </div>

# %%
data = {}
for item in about.find_all('div', {'class':'career__about-item'}):
    key = item.find('div').text.strip()
    value = item.find('p').text.strip()
    data[key] = value

emp_cnt = data.get('Количество сотрудников')
city = data.get('Город (головной офис)')
year_founded = data.get('Год основания')
industry = data.get('Отрасль')
print(emp_cnt, city, year_founded, industry)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_503/1180327013.py in <cell line: 0>()
#       2 for item in about.find_all('div', {'class':'career__about-item'}):
#       3     key = item.find('div').text.strip()
# ----> 4     value = item.find('p').text.strip()
#       5     data[key] = value
#       6
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
site = soup1.find('div', {'class': 'col-md-6 col-lg-4 career__about-item'}).find_all('span', {'onclick': "$(this).closest('form').submit()"})
site

# %%
descr = soup1.find_all('div', {'class': 'text-16 line-clamp-4'})[0].text.strip().replace("\xa0", "").replace("\n", "")
descr

# %%
def GetEmployer(url0):
    """
    Возвращает кортеж с url0, date, author, title.
    Параметры:

    url0 - ссылка на новость (строка).
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'html')


    #date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
    #title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')
    title = soup0.find_all('div', {'class': 'company__name line-clamp-2'})[0].text.strip() if soup0.find_all('div', {'class': 'company__name line-clamp-2'}) else None
    review = soup0.find_all('div', {'class': 'company__indicator-number'})[0].text.strip() if soup0.find_all('div', {'class': 'company__indicator-number'}) else None
    rec_share = soup0.find_all('div', {'class': 'company__indicator-number'})[1].text.strip() if soup0.find_all('div', {'class': 'company__indicator-number'}) else None
    review_cnts = soup0.find_all('span', {'class': 'tabs__count'})[0].text.strip().replace("\xa0", "") if soup0.find_all('span', {'class': 'tabs__count'})[0].text.strip() else None
    review_name = soup0.find_all('div', {'class': 'dashboard-sidebar__grade-humanly'})[0].text.strip() if soup0.find_all('div', {'class': 'dashboard-sidebar__grade-humanly'}) else None
    page1 = requests.get(url0+'/career')
    soup1 = BeautifulSoup(page1.text, 'html')
    about = soup1.find('div', {'class': 'row career__about-items'})
    data = {}
    for item in about.find_all('div', {'class':'career__about-item'}):
        key = item.find('div').text.strip() if item.find('div') else None
        value = item.find('p').text.strip() if item.find('p') else None
        data[key] = value

    emp_cnt = data.get('Количество сотрудников')
    city = data.get('Город (головной офис)')
    year_founded = data.get('Год основания')
    industry = data.get('Отрасль')
    site = soup1.find('div', {'class': 'col-md-6 col-lg-4 career__about-item'}).find('span', {'onclick': "$(this).closest('form').submit()"}).text.strip() if soup1.find('div', {'class': 'col-md-6 col-lg-4 career__about-item'}).find('span', {'onclick': "$(this).closest('form').submit()"}) else None
    descr = soup1.find('div', {'class': 'text-16 line-clamp-4'}).text.strip().replace("\xa0", "").replace("\n", "") if soup1.find('div', {'class': 'text-16 line-clamp-4'}) else None
    return title, review, rec_share, review_cnts, review_name, emp_cnt, city, year_founded, industry, site, descr

# %%
from time import sleep

# %%
employers = []

# %%
for link in urls:
    print(link)
    res = GetEmployer('https://dreamjob.ru/'+link)
    employers.append(res)

    #sleep(1) # задержка в 3 секунды
# Out:
# /employers/286960
# /employers/26066
# /employers/25908
# /employers/25924
# /employers/2672030
# /employers/6424
# /employers/6690
# /employers/26028
# /employers/25879
# /employers/26161
# /employers/37011
# /employers/56859
# /employers/25947
# /employers/46157
# /employers/25596
# /employers/93692
# /employers/25607
# /employers/37657
# /employers/26069
# /employers/25930
# /employers/25704
# /employers/25921
# /employers/25918
# /employers/25946
# /employers/26011
# /employers/26091
# /employers/56818
# /employers/25903
# /employers/26156
# /employers/25583
# /employers/258089
# /employers/25931
# /employers/26002
# /employers/25920
# /employers/26029
# /employers/58994
# /employers/104847

# %%
import pandas as pd

df = pd.DataFrame(employers)
df.head(2)
# Out:
#                            0    1    2      3       4            5       6   \
# 0          Розничная сеть МТС  3,3  48%   4012  Хорошо  более 10000  Москва
# 1  Российские железные дороги  3,7  70%  22383  Хорошо  более 10000  Москва
#
#      7                                 8                  9   \
# 0  2001                Розничная торговля            Перейти
# 1  2003  Перевозки, логистика, склад, ВЭД  http://www.rzd.ru
#
#                                                   10
# 0  Розничная сеть МТС – самый быстрый способ позн...
# 1                                               None

# %%
df.columns = ['title', 'review', 'rec_share', 'review_cnts', 'review_name', 'emp_cnt', 'city', 'year_founded', 'industry', 'site', 'descr']

# %%
df.to_excel('emp_dreamjob.xlsx', index=False)
